# %% [markdown]
# # Extract GEE data over all sites
#
# ## Setup
# For each site, extract the full time series of Sentinel-1,NDVI data from the GEE. Note: if the output csv files already exist they are assumed to be correct and are not over-written.

# %% [markdown]
# Setup the proxy

# %%
import os
import pandas as pd
import ee
import utils
os.environ['HTTP_PROXY'] = 'http://127.0.0.1:41091'
os.environ['HTTPS_PROXY'] = 'http://127.0.0.1:41091'
ee.Initialize()

# %% [markdown]
# Set the parameters, paths etc.

# %%
# Parameters for Sentinel-1 data
START_DATE = "2016-01-01"
END_DATE = "2019-12-31"  #
S1_PRODUCT = "COPERNICUS/S1_GRD"
ORBIT_PASS_A = 'ASCENDING'
ORBIT_PASS_D = 'DESCENDING'
S1_BANDS = ["VV",
            "VH",
            "angle"]
IN_MOD = 'IW'


# Parameters for NDVI data
START_DATE_NDVI = "2015-12-01" # two month extension for interpolation
END_DATE_NDVI = "2020-01-31" 
MOD_PRODUCT = "MODIS/006/MOD13Q1"
MYD_PRODUCT = "MODIS/006/MYD13Q1"
NDVI_BANDS = ["NDVI",
         "EVI"]
interpolate_bands = ['NDVI', 'EVI', 'SMAP']
# Global setups, dir, path
BUFFER = 50 # a buffer of 50m to have a resolution of around 100 m
save_to_disk = False # No temporal files

HOME_DIR = r"E:\Zoho WorkDrive (YICODE)\My Folders\TimeSeriesRetrieval\Extension"
SM_SITES = os.path.join(HOME_DIR, "site_info.csv") # the site informaiton extracted by Preprocessing_ISMN_Raw_Data.ipynb
SMAP_FILE = os.path.join(HOME_DIR, "SMAP\SMAP.csv") # the SMAP data extracted by Extract the SMAP soil moisture.ipynb
SM_DIR = os.path.join(HOME_DIR,"daily_ave")
INPUT_DIR = os.path.join(HOME_DIR,"input")
if not os.path.exists(INPUT_DIR):
    os.mkdir(INPUT_DIR)
NDVI_DIR = os.path.join(HOME_DIR,"NDVI")
S1_DIR = os.path.join(HOME_DIR,"sentinel1")

# %% [markdown]
# Read the sites information

# %%
sites = pd.read_csv(SM_SITES, float_precision="high")

# %% [markdown]
# ## A loop to prepare the input data of each site
# ###### 1 read the SMAP records for the site
# ###### 2 read the in-situ soil moisture
# ###### 3 extract the MYD and MOD NDVI over the site and merge the two NDVI series
# ###### 4 if ascending data was collected over the site, extract the ascending Sentinel-1 data and interpolate the NDVI and SMAP on all Sentinel-1 ascending acquisition dates
# ###### 5 if descending data was collected over the site, extract the descending Sentinel-1 data and interpolate the NDVI and SMAP on all Sentinel-1 Dscending acquisition dates
# ###### 6 concate all data and save
#
# ###### Note: the loop may report the error "IncompleteRead", just run this cell again.

# %%
from TimeseriesExtractor import GeeS1TimeseriesExtractor, GeeTimeseriesExtractor
# Global extractor for MYD13Q1 and MOD13Q1
MYD_Extractor = GeeTimeseriesExtractor(MYD_PRODUCT,NDVI_BANDS,START_DATE_NDVI,END_DATE_NDVI,NDVI_DIR,save_to_disk)
MOD_Extractor = GeeTimeseriesExtractor(MOD_PRODUCT,NDVI_BANDS,START_DATE_NDVI,END_DATE_NDVI,NDVI_DIR,save_to_disk)
# Read all related SMAP soil moisutre data
df_SMAP = pd.read_csv(SMAP_FILE,index_col='time',parse_dates=True)

for site_idx, site in sites.iterrows():
    if os.path.exists(os.path.join(INPUT_DIR,f'{site.network}_{site.station}.csv')):
        print(f'Site: {site.network}_{site.station}, Done before')
        df=pd.read_csv(os.path.join(INPUT_DIR,f'{site.network}_{site.station}.csv'))
        continue
    print(f'Extracting data for site: {site.network}_{site.station}')
    # Read SMAP data
    df_site_SMAP = df_SMAP['r%sc%s'%(site.EASE_row,site.EASE_column)]
    df_site_SMAP=df_site_SMAP.rename('SMAP')
    
    # Read ground sm measurements
    SM_site_file = os.path.join(SM_DIR, f'{site.network}_{site.station}.csv')
    df_gt = pd.read_csv(SM_site_file,index_col='time',parse_dates=True)
    
    # Extract NDVI
    site_geometry = ee.Geometry.Point(site.lon, site.lat)
    MYD=MYD_Extractor.download_data(site_geometry)
    MOD=MOD_Extractor.download_data(site_geometry)
    df_NDVI=pd.concat([MYD,MOD]).sort_index()
    df_NDVI[NDVI_BANDS]=df_NDVI[NDVI_BANDS].astype('float')/10000 # Remove the scale of 10000 
    df_NDVI=df_NDVI.groupby(level=0).mean()    
    
    # Setup for Sentinel-1 extraction
    site_geometry = ee.Geometry.Point(site.lon, site.lat).buffer(BUFFER) # Build GEE point geometry with a buffer
    df_all = pd.DataFrame(columns=['time','Excel_day', 'DoY', 'VV', 'VH', 'angle', 'relative_orbit', 'platform',
       'orbit_pass', 'NDVI', 'EVI', 'SMAP', 'sm', 'ts', 'sm_count']).set_index('time')
    
    # Extract Sentinel-1 Ascending data, interpolate the NDVI and SMAP on all Sentinel-1 Ascending acquisition dates
    S1_extractor_A = GeeS1TimeseriesExtractor(S1_PRODUCT,START_DATE, END_DATE,S1_BANDS,site_geometry,ORBIT_PASS_A,IN_MOD,S1_DIR,save_to_disk)
    if S1_extractor_A.image_size > 0:
        df_S1A = S1_extractor_A.get_and_save_data(f'{site.network}_{site.station}')
        # Merge S1,NDVI,SMAP and interpolate the NDVI and SMAP on all Sentinel-1 acquisition dates
        df_allA = pd.concat([df_S1A,df_NDVI,df_site_SMAP],axis=1).sort_index()   
        df_allA[interpolate_bands]=df_allA[interpolate_bands].interpolate(limit_area = 'inside')
        df_allA = pd.concat([df_allA, df_gt],axis=1)
        df_allA=df_allA.loc[df_S1A.index]; # only keep the dates with S1 observations 
        df_allA = df_allA.loc[:,~df_allA.columns.duplicated()] # remove duplicate columns
        df_all=df_all.append(df_allA)
        
    # Extract Sentinel-1 Ascending data, interpolate the NDVI and SMAP on all Sentinel-1 Dscending acquisition dates    
    S1_extractor_D = GeeS1TimeseriesExtractor(S1_PRODUCT,START_DATE, END_DATE,S1_BANDS,site_geometry,ORBIT_PASS_D,IN_MOD,S1_DIR,save_to_disk)
    if S1_extractor_D.image_size > 0:
        df_S1D = S1_extractor_D.get_and_save_data(f'{site.network}_{site.station}')
        df_allD = pd.concat([df_S1D,df_NDVI,df_site_SMAP],axis=1).sort_index()   
        df_allD[interpolate_bands]=df_allD[interpolate_bands].interpolate(limit_area = 'inside')
        df_allD = pd.concat([df_allD, df_gt],axis=1)
        df_allD=df_allD.loc[df_S1D.index]; # only keep the dates with S1 observations 
        df_allD = df_allD.loc[:,~df_allD.columns.duplicated()] # remove duplicate columns
        df_all=df_all.append(df_allD)

    # Save data
    df_all=df_all.sort_index()
    df_all.to_csv(os.path.join(INPUT_DIR,f'{site.network}_{site.station}.csv'))
# Out:
# Site: AMMA-CATCH_Banizoumbou, Done before
# Site: AMMA-CATCH_Belefoungou-Mid, Done before
# Site: AMMA-CATCH_Belefoungou-Top, Done before
# Site: AMMA-CATCH_Nalohou-Mid, Done before
# Site: AMMA-CATCH_Nalohou-Top, Done before
# Site: AMMA-CATCH_Tondikiboro, Done before
# Site: AMMA-CATCH_Wankama, Done before
# Site: PBO_H2O_Bethlehem, Done before
# Site: PBO_H2O_Mafikeng, Done before
# Site: PBO_H2O_Newcastle, Done before
# Site: PBO_H2O_Sutherland, Done before
# Site: PBO_H2O_Upington, Done before
# Site: SD_DEM_Demokeya, Done before
# Site: TAHMO_CRIG_(Soil_Moisture_Station_1), Done before
# Site: TAHMO_CRIG_(Soil_Moisture_Station_2), Done before
# Site: TAHMO_CSIR-SARI,_Nyankpala_-_Tamale, Done before
# Site: TAHMO_KNUST_Farm,_Kumasi, Done before
# Site: CTP_SMTMN_L01, Done before
# Site: CTP_SMTMN_L02, Done before
# Site: CTP_SMTMN_L03, Done before
# Site: CTP_SMTMN_L04_M02, Done before
# Site: CTP_SMTMN_L05_M06, Done before
# Site: CTP_SMTMN_L06_M10, Done before
# Site: CTP_SMTMN_L07_M13, Done before
# Site: CTP_SMTMN_L08_M14, Done before
# Site: CTP_SMTMN_L09_M16, Done before
# Site: CTP_SMTMN_L10_M17, Done before
# Site: CTP_SMTMN_L11_M21, Done before
# Site: CTP_SMTMN_L12_M22, Done before
# Site: CTP_SMTMN_L13, Done before
# Site: CTP_SMTMN_L14, Done before
# Site: CTP_SMTMN_L15, Done before
# Site: CTP_SMTMN_L16, Done before
# Site: CTP_SMTMN_L17, Done before
# Site: CTP_SMTMN_L18, Done before
# Site: CTP_SMTMN_L19, Done before
# Site: CTP_SMTMN_L20, Done before
# Site: CTP_SMTMN_L21, Done before
# Site: CTP_SMTMN_L22, Done before
# Site: CTP_SMTMN_L23, Done before
# Site: CTP_SMTMN_L24, Done before
# Site: CTP_SMTMN_L26, Done before
# Site: CTP_SMTMN_L27, Done before
# Site: CTP_SMTMN_L29, Done before
# Site: CTP_SMTMN_L31, Done before
# Site: CTP_SMTMN_L32, Done before
# Site: CTP_SMTMN_L33, Done before
# Site: CTP_SMTMN_L34, Done before
# Site: CTP_SMTMN_L35, Done before
# Site: CTP_SMTMN_L36, Done before
# Site: CTP_SMTMN_L37, Done before
# Site: CTP_SMTMN_L38, Done before
# Site: CTP_SMTMN_M01, Done before
# Site: CTP_SMTMN_M03, Done before
# Site: CTP_SMTMN_M04, Done before
# Site: CTP_SMTMN_M05, Done before
# Site: CTP_SMTMN_M07_S01, Done before
# Site: CTP_SMTMN_M08, Done before
# Site: CTP_SMTMN_M11_S09, Done before
# Site: CTP_SMTMN_M12_S08, Done before
# Site: CTP_SMTMN_M15, Done before
# Site: CTP_SMTMN_M18, Done before
# Site: CTP_SMTMN_M19, Done before
# Site: CTP_SMTMN_M20, Done before
# Site: CTP_SMTMN_S02, Done before
# Site: CTP_SMTMN_S03, Done before
# Site: CTP_SMTMN_S04, Done before
# Site: CTP_SMTMN_S05, Done before
# Site: CTP_SMTMN_S06, Done before
# Site: CTP_SMTMN_S07, Done before
# Site: MAQU_CST_03, Done before
# Site: MAQU_CST_04, Done before
# Site: MAQU_CST_05, Done before
# Site: MAQU_NST_01, Done before
# Site: MAQU_NST_03, Done before
# Site: MAQU_NST_05, Done before
# Site: MAQU_NST_06, Done before
# Site: MAQU_NST_07, Done before
# Site: MAQU_NST_08, Done before
# Site: MAQU_NST_09, Done before
# Site: MAQU_NST_10, Done before
# Site: MAQU_NST_24, Done before
# Site: MAQU_NST_25, Done before
# Site: MAQU_NST_30, Done before
# Site: MAQU_NST_31, Done before
# Site: MAQU_NST_32, Done before
# Site: NAQU_NQ01, Done before
# Site: NAQU_NQ02, Done before
# Site: NAQU_NQ03, Done before
# Site: NAQU_NQ04, Done before
# Site: NAQU_NQ_BJ, Done before
# Site: NAQU_NQ_Kema, Done before
# Site: NAQU_NQ_MS, Done before
# Site: NAQU_NQ_North, Done before
# Site: NAQU_NQ_West, Done before
# Site: NGARI_ALI01, Done before
# Site: NGARI_ALI02, Done before
# Site: NGARI_ALI03, Done before
# Site: NGARI_SQ01, Done before
# Site: NGARI_SQ02, Done before
# Site: NGARI_SQ03, Done before
# Site: NGARI_SQ06, Done before
# Site: NGARI_SQ07, Done before
# Site: NGARI_SQ08, Done before
# Site: NGARI_SQ10, Done before
# Site: NGARI_SQ11, Done before
# Site: NGARI_SQ14, Done before
# Site: NGARI_SQ17, Done before
# Site: NGARI_SQ18, Done before
# Site: NGARI_SQ19, Done before
# Site: NGARI_SQ20, Done before
# Site: NGARI_SQ21, Done before
# Site: OZNET_Alabama, Done before
# Site: OZNET_Banandra, Done before
# Site: OZNET_Bundure, Done before
# Site: OZNET_Cheverelis, Done before
# Site: OZNET_Cox, Done before
# Site: OZNET_Dry_Lake, Done before
# Site: OZNET_Eulo, Done before
# Site: OZNET_Evergreen, Done before
# Site: OZNET_Kyeamba_Mouth, Done before
# Site: OZNET_S_Coleambally, Done before
# Site: OZNET_Samarra, Done before
# Site: OZNET_Silver_Springs, Done before
# Site: OZNET_Spring_Bank, Done before
# Site: OZNET_Uri_Park, Done before
# Site: OZNET_Widgiewa, Done before
# Site: OZNET_Wollumbi, Done before
# Site: OZNET_Wynella, Done before
# Site: OZNET_Yamma_Road, Done before
# Site: OZNET_Yammacoona, Done before
# Site: SMN-SDR_L1, Done before
# Site: SMN-SDR_L10, Done before
# Site: SMN-SDR_L11, Done before
# Site: SMN-SDR_L12, Done before
# Site: SMN-SDR_L13, Done before
# Site: SMN-SDR_L14, Done before
# Site: SMN-SDR_L2, Done before
# Site: SMN-SDR_L3, Done before
# Site: SMN-SDR_L4, Done before
# Site: SMN-SDR_L5, Done before
# Site: SMN-SDR_L6, Done before
# Site: SMN-SDR_L7, Done before
# Site: SMN-SDR_L8, Done before
# Site: SMN-SDR_L9, Done before
# Site: SMN-SDR_M1, Done before
# Site: SMN-SDR_M10, Done before
# Site: SMN-SDR_M11, Done before
# Site: SMN-SDR_M12, Done before
# Site: SMN-SDR_M2, Done before
# Site: SMN-SDR_M3, Done before
# Site: SMN-SDR_M4, Done before
# Site: SMN-SDR_M5, Done before
# Site: SMN-SDR_M6, Done before
# Site: SMN-SDR_M7, Done before
# Site: SMN-SDR_M8, Done before
# Site: SMN-SDR_M9, Done before
# Site: SMN-SDR_S1, Done before
# Site: SMN-SDR_S2, Done before
# Site: SMN-SDR_S3, Done before
# Site: SMN-SDR_S4, Done before
# Site: SMN-SDR_S5, Done before
# Site: SMN-SDR_S6, Done before
# Site: SMN-SDR_S7, Done before
# Site: SMN-SDR_S8, Done before
# Site: BIEBRZA_S-1_grassland_soil_1, Done before
# Site: BIEBRZA_S-1_grassland_soil_2, Done before
# Site: BIEBRZA_S-1_grassland_soil_3, Done before
# Site: BIEBRZA_S-1_grassland_soil_4, Done before
# Site: BIEBRZA_S-1_grassland_soil_5, Done before
# Site: BIEBRZA_S-1_grassland_soil_6, Done before
# Site: BIEBRZA_S-1_grassland_soil_7, Done before
# Site: BIEBRZA_S-1_grassland_soil_8, Done before
# Site: BIEBRZA_S-1_grassland_soil_9, Done before
# Site: BIEBRZA_S-1_marshland_soil_11, Done before
# Site: BIEBRZA_S-1_marshland_soil_12, Done before
# Site: BIEBRZA_S-1_marshland_soil_13, Done before
# Site: BIEBRZA_S-1_marshland_soil_14, Done before
# Site: BIEBRZA_S-1_marshland_soil_15, Done before
# Site: BIEBRZA_S-1_marshland_soil_16, Done before
# Site: BIEBRZA_S-1_marshland_soil_17, Done before
# Site: BIEBRZA_S-1_marshland_soil_18, Done before
# Site: BIEBRZA_S-1_marshland_soil_19, Done before
# Site: FMI_SAA111, Done before
# Site: FMI_SAA112, Done before
# Site: FMI_SAA120, Done before
# Site: FMI_SOD011, Done before
# Site: FMI_SOD013, Done before
# Site: FMI_SOD021, Done before
# Site: FMI_SOD071, Done before
# Site: FMI_SOD072, Done before
# Site: FMI_SOD073, Done before
# Site: FMI_SOD081, Done before
# Site: FMI_SOD083, Done before
# Site: FMI_SOD091, Done before
# Site: FMI_SOD092, Done before
# Site: FMI_SOD093, Done before
# Site: FMI_SOD101, Done before
# Site: FMI_SOD102, Done before
# Site: FMI_SOD103, Done before
# Site: FMI_SOD130, Done before
# Site: FMI_SOD140, Done before
# Site: FMI_SODAWS, Done before
# Site: FR_Aqui_fraye, Done before
# Site: FR_Aqui_grandcal, Done before
# Site: FR_Aqui_hillan2, Done before
# Site: FR_Aqui_parcmeteo, Done before
# Site: HOAL_Hoal_01, Done before
# Site: HOAL_Hoal_02, Done before
# Site: HOAL_Hoal_04, Done before
# Site: HOAL_Hoal_05, Done before
# Site: HOAL_Hoal_06, Done before
# Site: HOAL_Hoal_07, Done before
# Site: HOAL_Hoal_08, Done before
# Site: HOAL_Hoal_09, Done before
# Site: HOAL_Hoal_10, Done before
# Site: HOAL_Hoal_11, Done before
# Site: HOAL_Hoal_12, Done before
# Site: HOAL_Hoal_13, Done before
# Site: HOAL_Hoal_14, Done before
# Site: HOAL_Hoal_15, Done before
# Site: HOAL_Hoal_16, Done before
# Site: HOAL_Hoal_17, Done before
# Site: HOAL_Hoal_18, Done before
# Site: HOAL_Hoal_19, Done before
# Site: HOAL_Hoal_21, Done before
# Site: HOAL_Hoal_22, Done before
# Site: HOAL_Hoal_24, Done before
# Site: HOAL_Hoal_25, Done before
# Site: HOAL_Hoal_26, Done before
# Site: HOAL_Hoal_27, Done before
# Site: HOAL_Hoal_28, Done before
# Site: HOAL_Hoal_29, Done before
# Site: HOAL_Hoal_30, Done before
# Site: HOAL_Hoal_32, Done before
# Site: HOAL_Hoal_33, Done before
# Site: HOAL_Hoal_34, Done before
# Site: HOAL_Hoal_35, Done before
# Site: HOAL_Hoal_36, Done before
# Site: HOBE_1.01, Done before
# Site: HOBE_1.02, Done before
# Site: HOBE_1.03, Done before
# Site: HOBE_1.04, Done before
# Site: HOBE_1.05, Done before
# Site: HOBE_1.06, Done before
# Site: HOBE_1.07, Done before
# Site: HOBE_1.08, Done before
# Site: HOBE_1.09, Done before
# Site: HOBE_1.1, Done before
# Site: HOBE_2.01, Done before
# Site: HOBE_2.03, Done before
# Site: HOBE_2.04, Done before
# Site: HOBE_2.05, Done before
# Site: HOBE_2.06b, Done before
# Site: HOBE_2.07, Done before
# Site: HOBE_2.08b, Done before
# Site: HOBE_2.09, Done before
# Site: HOBE_2.1, Done before
# Site: HOBE_2.11, Done before
# Site: HOBE_3.01, Done before
# Site: HOBE_3.02, Done before
# Site: HOBE_3.03, Done before
# Site: HOBE_3.04, Done before
# Site: HOBE_3.05, Done before
# Site: HOBE_3.06, Done before
# Site: HOBE_3.07, Done before
# Site: HOBE_3.08, Done before
# Site: HOBE_3.09, Done before
# Site: HYDROL-NET_PERUGIA_Water_Engineering_Experimental_Field_1, Done before
# Site: HYDROL-NET_PERUGIA_Water_Engineering_Experimental_Field_2, Done before
# Site: REMEDHUS_Canizal, Done before
# Site: REMEDHUS_Carretoro, Done before
# Site: REMEDHUS_Casa_Periles, Done before
# Site: REMEDHUS_Concejo_del_Monte, Done before
# Site: REMEDHUS_El_Coto, Done before
# Site: REMEDHUS_El_Tomillar, Done before
# Site: REMEDHUS_Granja_g, Done before
# Site: REMEDHUS_Guarrati, Done before
# Site: REMEDHUS_La_Atalaya, Done before
# Site: REMEDHUS_La_Cruz_de_Elias, Done before
# Site: REMEDHUS_Las_Arenas, Done before
# Site: REMEDHUS_Las_Bodegas, Done before
# Site: REMEDHUS_Las_Brozas, Done before
# Site: REMEDHUS_Las_Eritas, Done before
# Site: REMEDHUS_Las_Tres_Rayas, Done before
# Site: REMEDHUS_Las_Vacas, Done before
# Site: REMEDHUS_Las_Victorias, Done before
# Site: REMEDHUS_Llanos_de_la_Boveda, Done before
# Site: REMEDHUS_Paredinas, Done before
# Site: REMEDHUS_Zamarron, Done before
# Site: RSMN_Alexandria, Done before
# Site: RSMN_Bacles, Done before
# Site: RSMN_Banloc, Done before
# Site: RSMN_Barlad, Done before
# Site: RSMN_Calarasi, Done before
# Site: RSMN_Chisineu_Cris, Done before
# Site: RSMN_Corugea, Done before
# Site: RSMN_Cotnari, Done before
# Site: RSMN_Darabani, Done before
# Site: RSMN_Dej, Done before
# Site: RSMN_Dumbraveni, Done before
# Site: RSMN_Iasi, Done before
# Site: RSMN_Oradea, Done before
# Site: RSMN_Rosiorii_de_Vede, Done before
# Site: RSMN_Sannicolau_Mare, Done before
# Site: RSMN_Satu_Mare, Done before
# Site: RSMN_Slatina, Done before
# Site: RSMN_Slobozia, Done before
# Site: RSMN_Tecuci, Done before
# Site: Ru_CFR_Fyodorovskoye_dry_spruce_stand, Done before
# Site: Ru_CFR_Fyodorovskoye_wet_spruce_stand, Done before
# Site: SMOSMANIA_Barnas, Done before
# Site: SMOSMANIA_Berzeme, Done before
# Site: SMOSMANIA_Cabrieres_dAvignon, Done before
# Site: SMOSMANIA_Condom, Done before
# Site: SMOSMANIA_Creon_dArmagnac, Done before
# Site: SMOSMANIA_La_Grand_Combe, Done before
# Site: SMOSMANIA_Lahas, Done before
# Site: SMOSMANIA_Lezignan_Corbieres, Done before
# Site: SMOSMANIA_Mazan-Abbaye, Done before
# Site: SMOSMANIA_Mejannes-le-Clap, Done before
# Site: SMOSMANIA_Montaut, Done before
# Site: SMOSMANIA_Mouthoumet, Done before
# Site: SMOSMANIA_Narbonne, Done before
# Site: SMOSMANIA_Peyrusse_Grande, Done before
# Site: SMOSMANIA_Pezenas, Done before
# Site: SMOSMANIA_Pezenas_old, Done before
# Site: SMOSMANIA_Prades-le-Lez, Done before
# Site: SMOSMANIA_Sabres, Done before
# Site: SMOSMANIA_Saint_Felix_de_Lauragais, Done before
# Site: SMOSMANIA_Savenes, Done before
# Site: SMOSMANIA_Urgons, Done before
# Site: SMOSMANIA_Villevielle, Done before
# Site: TERENO_Gevenich, Done before
# Site: TERENO_Merzenhausen, Done before
# Site: TERENO_Schoeneseiffen, Done before
# Site: TERENO_Selhausen, Done before
# Site: TERENO_Wildenrath, Done before
# Site: WSMN_WSMN_1, Done before
# Site: WSMN_WSMN_2, Done before
# Site: WSMN_WSMN_3, Done before
# Site: WSMN_WSMN_4, Done before
# Site: ARM_Anthony, Done before
# Site: ARM_Ashton, Done before
# Site: ARM_Byron, Done before
# Site: ARM_Lamont_CF1, Done before
# Site: ARM_Maple_City, Done before
# Site: ARM_Marshall, Done before
# Site: ARM_Medford, Done before
# Site: ARM_Morrison, Done before
# Site: ARM_Newkirk, Done before
# Site: ARM_Omega, Done before
# Site: ARM_Pawhuska, Done before
# Site: ARM_Ringwood, Done before
# Site: ARM_Tryon, Done before
# Site: ARM_Tyro, Done before
# Site: ARM_Waukomis, Done before
# Site: FLUXNET-AMERIFLUX_Bouldin_Island_Alfalfa, Done before
# Site: FLUXNET-AMERIFLUX_Bouldin_Island_corn, Done before
# Site: FLUXNET-AMERIFLUX_Sherman_Barn, Done before
# Site: FLUXNET-AMERIFLUX_Tonzi_Ranch, Done before
# Site: FLUXNET-AMERIFLUX_Vaira_Ranch, Done before
# Site: iRON_Brush_Creek, Done before
# Site: iRON_Glassier_Ranch, Done before
# Site: iRON_Glenwood_Springs, Done before
# Site: iRON_Independence_Pass, Done before
# Site: iRON_Northstar_Aspen_Grove, Done before
# Site: iRON_Northstar_Transition_Zone, Done before
# Site: iRON_Sky_Mountain, Done before
# Site: iRON_Smuggler_Mountain, Done before
# Site: iRON_Spring_Valley, Done before
# Site: PBO_H2O_ALKALILAKE, Done before
# Site: PBO_H2O_ANGELFIRE, Done before
# Site: PBO_H2O_ANGUS_PROP, Done before
# Site: PBO_H2O_ANTIMONYFL, Done before
# Site: PBO_H2O_ARKANSACRK, Done before
# Site: PBO_H2O_ARMINGTON, Done before
# Site: PBO_H2O_ATOMICCITY, Done before
# Site: PBO_H2O_AUBREYPEAK, Done before
# Site: PBO_H2O_AVILARANCH, Done before
# Site: PBO_H2O_BAKERCITY, Done before
# Site: PBO_H2O_BANDONARPT, Done before
# Site: PBO_H2O_BILLINGSAP, Done before
# Site: PBO_H2O_BIRCHIMCYN, Done before
# Site: PBO_H2O_BITTERWATR, Done before
# Site: PBO_H2O_BKAP_SCGN, Done before
# Site: PBO_H2O_BLACKROCK, Done before
# Site: PBO_H2O_BLINDSPRIN, Done before
# Site: PBO_H2O_BROTHERSDT, Done before
# Site: PBO_H2O_BUCKLEYFLT, Done before
# Site: PBO_H2O_BUCKSKINMT, Done before
# Site: PBO_H2O_BUTTERBRED, Done before
# Site: PBO_H2O_BUZZARDRST, Done before
# Site: PBO_H2O_CABOROJO, Done before
# Site: PBO_H2O_CALAVERAS, Done before
# Site: PBO_H2O_CALCITYAPT, Done before
# Site: PBO_H2O_CALCITYPLR, Done before
# Site: PBO_H2O_CALIVALLEY, Done before
# Site: PBO_H2O_CAMPELLIOT, Done before
# Site: PBO_H2O_CARRIZORAN, Done before
# Site: PBO_H2O_CERREJON, Done before
# Site: PBO_H2O_CERRILLOS, Done before
# Site: PBO_H2O_CHILEOFLAT, Done before
# Site: PBO_H2O_CLAYTONARP, Done before
# Site: PBO_H2O_CN02, Done before
# Site: PBO_H2O_CN07, Done before
# Site: PBO_H2O_COXCOMBMTN, Done before
# Site: PBO_H2O_CRRS_SCGN, Done before
# Site: PBO_H2O_CSCI_SCGN, Done before
# Site: PBO_H2O_CTDM_SCGN, Done before
# Site: PBO_H2O_DELANO_AIR, Done before
# Site: PBO_H2O_DELTAMUNI, Done before
# Site: PBO_H2O_DELVALLE, Done before
# Site: PBO_H2O_DRI_RENO, Done before
# Site: PBO_H2O_DRYMOUNTAI, Done before
# Site: PBO_H2O_EcRockStPkTX2012, Done before
# Site: PBO_H2O_ENNISFISH, Done before
# Site: PBO_H2O_FALLBROOK, Done before
# Site: PBO_H2O_FGST_SCGN, Done before
# Site: PBO_H2O_FORDRA087G, Done before
# Site: PBO_H2O_FOUNTGREEN, Done before
# Site: PBO_H2O_FREEMONTAP, Done before
# Site: PBO_H2O_GLRS_SCGN, Done before
# Site: PBO_H2O_GNPS_SCGN, Done before
# Site: PBO_H2O_GRANITEMTN, Done before
# Site: PBO_H2O_GRANITEPK, Done before
# Site: PBO_H2O_GRANTS, Done before
# Site: PBO_H2O_GRAPEVINE, Done before
# Site: PBO_H2O_HARTMTNNWR, Done before
# Site: PBO_H2O_HAYSPEAK, Done before
# Site: PBO_H2O_HILL72, Done before
# Site: PBO_H2O_HILLMRANCHM, Done before
# Site: PBO_H2O_HLFISLPARK, Done before
# Site: PBO_H2O_HLFSTORYRN, Done before
# Site: PBO_H2O_HNSLVALLY, Done before
# Site: PBO_H2O_HORSHEAVEN, Done before
# Site: PBO_H2O_HUNT_SCGN, Done before
# Site: PBO_H2O_HVYS_SCGN, Done before
# Site: PBO_H2O_IMPERIALSP, Done before
# Site: PBO_H2O_IMPS_SCGN, Done before
# Site: PBO_H2O_INDIANPEAK, Done before
# Site: PBO_H2O_JACKASSBUT, Done before
# Site: PBO_H2O_KAMASLLOYD, Done before
# Site: PBO_H2O_KEMMERERLF, Done before
# Site: PBO_H2O_KNOLLSWEST, Done before
# Site: PBO_H2O_LAKHENSHAW, Done before
# Site: PBO_H2O_LAMARARPT, Done before
# Site: PBO_H2O_LASTCHANCE, Done before
# Site: PBO_H2O_LITTLEBALD, Done before
# Site: PBO_H2O_LITTLELOST, Done before
# Site: PBO_H2O_MARSHALL2, Done before
# Site: PBO_H2O_MASW_SCGN, Done before
# Site: PBO_H2O_MATADORRCH, Done before
# Site: PBO_H2O_MCDERMITT, Done before
# Site: PBO_H2O_MCDNLDWELL, Done before
# Site: PBO_H2O_MEDICINELG, Done before
# Site: PBO_H2O_MIDDLEGATE, Done before
# Site: PBO_H2O_MONTICELLO, Done before
# Site: PBO_H2O_MOONEYCYN, Done before
# Site: PBO_H2O_MORROCREEK, Done before
# Site: PBO_H2O_MORROWAIR, Done before
# Site: PBO_H2O_MT_GLEASON, Done before
# Site: PBO_H2O_NDAP_SCGN, Done before
# Site: PBO_H2O_NIPOMO, Done before
# Site: PBO_H2O_Okla2, Done before
# Site: PBO_H2O_OWENSGORGE, Done before
# Site: PBO_H2O_PARKINSONF, Done before
# Site: PBO_H2O_POINT_LOMA, Done before
# Site: PBO_H2O_PORTALESAP, Done before
# Site: PBO_H2O_QCY2_BARD, Done before
# Site: PBO_H2O_QUILLAYUT, Done before
# Site: PBO_H2O_RANDOLPHLL, Done before
# Site: PBO_H2O_RAWLINSWWT, Done before
# Site: PBO_H2O_REDKNOLLS, Done before
# Site: PBO_H2O_REIDHILLVW, Done before
# Site: PBO_H2O_RIFLE_GCL, Done before
# Site: PBO_H2O_ROSASCYN, Done before
# Site: PBO_H2O_SAGEVALLEY, Done before
# Site: PBO_H2O_SALMONFALL, Done before
# Site: PBO_H2O_SANPETEVAL, Done before
# Site: PBO_H2O_SanSalvador, Done before
# Site: PBO_H2O_SCIA_SCGN, Done before
# Site: PBO_H2O_SDHL_SCGN, Done before
# Site: PBO_H2O_SEVILLETA_#1, Done before
# Site: PBO_H2O_SEVILLETA_#2, Done before
# Site: PBO_H2O_SHANIKO, Done before
# Site: PBO_H2O_SHOSHONERV, Done before
# Site: PBO_H2O_SIERRAARMY, Done before
# Site: PBO_H2O_SILVERLAKE, Done before
# Site: PBO_H2O_SISTERSHSL, Done before
# Site: PBO_H2O_SLAVENCYN, Done before
# Site: PBO_H2O_SMAPSITEA2, Done before
# Site: PBO_H2O_SPARLINRCH, Done before
# Site: PBO_H2O_SPIDERROCK, Done before
# Site: PBO_H2O_SPRECKLESS, Done before
# Site: PBO_H2O_SPRINGCREK, Done before
# Site: PBO_H2O_TENSLEEPTR, Done before
# Site: PBO_H2O_TEPUSQUET, Done before
# Site: PBO_H2O_TRESPIEDRA, Done before
# Site: PBO_H2O_TUBA_CITY, Done before
# Site: PBO_H2O_VAUGHNPTRL, Done before
# Site: PBO_H2O_VERNONHILL, Done before
# Site: PBO_H2O_VIDALJUNCT, Done before
# Site: PBO_H2O_VIGUSBUTTE, Done before
# Site: PBO_H2O_VIMT_SCGN, Done before
# Site: PBO_H2O_VINAHELITK, Done before
# Site: PBO_H2O_WAGONMOUND, Done before
# Site: PBO_H2O_WANSHIP2, Done before
# Site: PBO_H2O_WHEATLAND, Done before
# Site: PBO_H2O_WHITEWATER, Done before
# Site: PBO_H2O_WICKSRANCH, Done before
# Site: PBO_H2O_WILBURLEVA, Done before
# Site: PBO_H2O_WOODLANDFM, Done before
# Site: PBO_H2O_WRIGHTSPT, Done before
# Site: RISMA_CEF, Done before
# Site: RISMA_MB1, Done before
# Site: RISMA_MB10, Done before
# Site: RISMA_MB11, Done before
# Site: RISMA_MB12, Done before
# Site: RISMA_MB13, Done before
# Site: RISMA_MB2, Done before
# Site: RISMA_MB3, Done before
# Site: RISMA_MB4, Done before
# Site: RISMA_MB5, Done before
# Site: RISMA_MB6, Done before
# Site: RISMA_MB7, Done before
# Site: RISMA_MB8, Done before
# Site: RISMA_MB9, Done before
# Site: RISMA_ON2, Done before
# Site: RISMA_ON3, Done before
# Site: RISMA_ON4, Done before
# Site: RISMA_ON5, Done before
# Site: RISMA_ON6, Done before
# Site: RISMA_SK1, Done before
# Site: RISMA_SK2, Done before
# Site: RISMA_SK3, Done before
# Site: RISMA_SK4, Done before
# Site: SCAN_AAMU-jtg, Done before
# Site: SCAN_Abrams, Done before
# Site: SCAN_Adams_Ranch_#1, Done before
# Site: SCAN_Alcalde, Done before
# Site: SCAN_Alkali_Mesa, Done before
# Site: SCAN_Allen_Farms, Done before
# Site: SCAN_Ames, Done before
# Site: SCAN_Ash_Valley, Done before
# Site: SCAN_Beasley_Lake, Done before
# Site: SCAN_Beaumont, Done before
# Site: SCAN_Blue_Creek, Done before
# Site: SCAN_Bodie_Hills, Done before
# Site: SCAN_Bosque_Seco, Done before
# Site: SCAN_Bragg_Farm, Done before
# Site: SCAN_Broad_Acres, Done before
# Site: SCAN_Buckhorn, Done before
# Site: SCAN_Buffalo_Jump, Done before
# Site: SCAN_Busby_Farm, Done before
# Site: SCAN_Bushland_#1, Done before
# Site: SCAN_Cache_Junction, Done before
# Site: SCAN_Carver_Farm, Done before
# Site: SCAN_Cave_Valley, Done before
# Site: SCAN_Centralia_Lake, Done before
# Site: SCAN_Charkiln, Done before
# Site: SCAN_Chicken_Ridge, Done before
# Site: SCAN_Circleville, Done before
# Site: SCAN_CMRB_LTAR-MO, Done before
# Site: SCAN_Cochora_Ranch, Done before
# Site: SCAN_Combate, Done before
# Site: SCAN_Conrad_Ag_Rc, Done before
# Site: SCAN_Cook_Farm_Field_D, Done before
# Site: SCAN_Corozal, Done before
# Site: SCAN_Cper, Done before
# Site: SCAN_Crescent_Lake_#1, Done before
# Site: SCAN_Cullman-NAHRC, Done before
# Site: SCAN_Death_Valley_JCT, Done before
# Site: SCAN_Deep_Springs, Done before
# Site: SCAN_Dee_River_Ranch, Done before
# Site: SCAN_Desert_Center, Done before
# Site: SCAN_Dexter, Done before
# Site: SCAN_Doe_Ridge, Done before
# Site: SCAN_Eagle_Lake, Done before
# Site: SCAN_Eastland, Done before
# Site: SCAN_Eastview_Farm, Done before
# Site: SCAN_Elsberry_PMC, Done before
# Site: SCAN_Enterprise, Done before
# Site: SCAN_Ephraim, Done before
# Site: SCAN_Eros_Data_Center, Done before
# Site: SCAN_Essex, Done before
# Site: SCAN_Everglades_Ars, Done before
# Site: SCAN_Ford_Dry_Lake, Done before
# Site: SCAN_Fort_Assiniboine_#1, Done before
# Site: SCAN_Fort_Reno_#1, Done before
# Site: SCAN_Fortuna, Done before
# Site: SCAN_French_Gulch, Done before
# Site: SCAN_Geneva_#1, Done before
# Site: SCAN_Glacial_Ridge, Done before
# Site: SCAN_Goodwin_Creek_Pasture, Done before
# Site: SCAN_Goodwin_Creek_Timber, Done before
# Site: SCAN_Goshute, Done before
# Site: SCAN_Grantsville, Done before
# Site: SCAN_Green_River, Done before
# Site: SCAN_Grouse_Creek, Done before
# Site: SCAN_Guilarte_Forest, Done before
# Site: SCAN_Hals_Canyon, Done before
# Site: SCAN_Harms_Way, Done before
# Site: SCAN_Hodges, Done before
# Site: SCAN_Holden, Done before
# Site: SCAN_Hubbard_Brook, Done before
# Site: SCAN_Isabela, Done before
# Site: SCAN_Isbell_Farms, Done before
# Site: SCAN_Johnson_Farm, Done before
# Site: SCAN_Jordan, Done before
# Site: SCAN_Jordan_Valley_Cwma, Done before
# Site: SCAN_Jornada_Exp_Range, Done before
# Site: SCAN_Journagan_Ranch, Done before
# Site: SCAN_Kingsville, Done before
# Site: SCAN_Knox_City, Done before
# Site: SCAN_Koptis_Farms, Done before
# Site: SCAN_Ku-nesa, Done before
# Site: SCAN_Kyle_Canyon, Done before
# Site: SCAN_Levelland, Done before
# Site: SCAN_Lind_#1, Done before
# Site: SCAN_LINDSAY, Done before
# Site: SCAN_Little_Red_Fox, Done before
# Site: SCAN_Little_River, Done before
# Site: SCAN_Livingston-UWA, Done before
# Site: SCAN_Los_Lunas_Pmc, Done before
# Site: SCAN_Lovell_Summit, Done before
# Site: SCAN_Lovelock_Nnr, Done before
# Site: SCAN_Lye_Brook, Done before
# Site: SCAN_Lynhart_Ranch, Done before
# Site: SCAN_Mahantango_Ck, Done before
# Site: SCAN_Mammoth_Cave, Done before
# Site: SCAN_Mandan_#1, Done before
# Site: SCAN_Manderfield, Done before
# Site: SCAN_Marble_Creek, Done before
# Site: SCAN_Maricao_Forest, Done before
# Site: SCAN_Mark_Twain_HS, Done before
# Site: SCAN_Mason_#1, Done before
# Site: SCAN_Mayday, Done before
# Site: SCAN_Mcalister_Farm, Done before
# Site: SCAN_Mccracken_Mesa, Done before
# Site: SCAN_Milford, Done before
# Site: SCAN_Moccasin, Done before
# Site: SCAN_Molly_Caren_#1, Done before
# Site: SCAN_Monocline_Ridge, Done before
# Site: SCAN_Morgan, Done before
# Site: SCAN_Morris_Farms, Done before
# Site: SCAN_Mountain_Home, Done before
# Site: SCAN_Mount_Mansfield, Done before
# Site: SCAN_Mt_Vernon, Done before
# Site: SCAN_Nephi, Done before
# Site: SCAN_North_Issaquena, Done before
# Site: SCAN_N_Piedmont_Arec, Done before
# Site: SCAN_Nunn_#1, Done before
# Site: SCAN_Onward, Done before
# Site: SCAN_Orchard_Range_Site, Done before
# Site: SCAN_Panguitch, Done before
# Site: SCAN_Park_Valley, Done before
# Site: SCAN_Pee_Dee, Done before
# Site: SCAN_Perdido_Riv_Farms, Done before
# Site: SCAN_Perthshire, Done before
# Site: SCAN_Phillipsburg, Done before
# Site: SCAN_Pine_Nut, Done before
# Site: SCAN_Porter_Canyon, Done before
# Site: SCAN_Powder_Mill, Done before
# Site: SCAN_Powell_Gardens, Done before
# Site: SCAN_Prairie_View_#1, Done before
# Site: SCAN_Price, Done before
# Site: SCAN_Princeton_#1, Done before
# Site: SCAN_Reynolds_Homestead, Done before
# Site: SCAN_Riesel, Done before
# Site: SCAN_River_Road_Farms, Done before
# Site: SCAN_Rock_Springs_Pa, Done before
# Site: SCAN_Rogers_Farm_#1, Done before
# Site: SCAN_San_Angelo, Done before
# Site: SCAN_Sand_Hollow, Done before
# Site: SCAN_Sandy_Ridge, Done before
# Site: SCAN_Schell-Osage, Done before
# Site: SCAN_Scott, Done before
# Site: SCAN_Sellers_Lake_#1, Done before
# Site: SCAN_Selma, Done before
# Site: SCAN_Sevilleta, Done before
# Site: SCAN_Shadow_Mtns, Done before
# Site: SCAN_Shagbark_Hills, Done before
# Site: SCAN_Shaw_Nature_Reserve, Done before
# Site: SCAN_SHELDON, Done before
# Site: SCAN_Shenandoah, Done before
# Site: SCAN_Sidney, Done before
# Site: SCAN_Silver_City, Done before
# Site: SCAN_Spickard, Done before
# Site: SCAN_Split_Mountain, Done before
# Site: SCAN_Spooky, Done before
# Site: SCAN_Stanley_Farm, Done before
# Site: SCAN_Starkville, Done before
# Site: SCAN_Stephenville, Done before
# Site: SCAN_Stubblefield, Done before
# Site: SCAN_Sudduth_Farms, Done before
# Site: SCAN_Sunleaf_Nursery, Done before
# Site: SCAN_TABLE_MOUNTAIN, Done before
# Site: SCAN_Tidewater_#1, Done before
# Site: SCAN_Tidewater_Arec, Done before
# Site: SCAN_TNC_Fort_Bayou, Done before
# Site: SCAN_Torrington_#1, Done before
# Site: SCAN_Trough_Springs, Done before
# Site: SCAN_Tule_Valley, Done before
# Site: SCAN_Tunica, Done before
# Site: SCAN_Tuskegee, Done before
# Site: SCAN_Twin_Pines_Conservation_Area, Done before
# Site: SCAN_UAPB_Campus-PB, Done before
# Site: SCAN_UAPB_Dewitt, Done before
# Site: SCAN_UAPB_Earle, Done before
# Site: SCAN_UAPB_Lonoke_Farm, Done before
# Site: SCAN_UAPB_Marianna, Done before
# Site: SCAN_UAPB_Point_Remove, Done before
# Site: SCAN_Uvalde, Done before
# Site: SCAN_Uw_Platteville, Done before
# Site: SCAN_Vance, Done before
# Site: SCAN_Vermillion, Done before
# Site: SCAN_Vernon, Done before
# Site: SCAN_Violett, Done before
# Site: SCAN_Wabeno_#1, Done before
# Site: SCAN_Wakulla_#1, Done before
# Site: SCAN_Walnut_Gulch_#1, Done before
# Site: SCAN_Watkinsville_#1, Done before
# Site: SCAN_Wedowee, Done before
# Site: SCAN_Weslaco, Done before
# Site: SCAN_West_Summit, Done before
# Site: SCAN_WTARS, Done before
# Site: SCAN_Youmans_Farm, Done before
# Site: SNOTEL_AGUA_CANYON, Done before
# Site: SNOTEL_ANNIE_SPRINGS, Done before
# Site: SNOTEL_ARAPAHO_RIDGE, Done before
# Site: SNOTEL_ATLANTA_SUMMIT, Done before
# Site: SNOTEL_Baker_Butte, Done before
# Site: SNOTEL_BAKER_BUTTE_SMT, Done before
# Site: SNOTEL_BALDY, Done before
# Site: SNOTEL_BANNER_SUMMIT, Done before
# Site: SNOTEL_Bar_M, Done before
# Site: SNOTEL_BEAR_CREEK, Done before
# Site: SNOTEL_BEAR_RIVER_RS, Done before
# Site: SNOTEL_BEAVER_DAMS, Done before
# Site: SNOTEL_BEAVER_DIVIDE, Done before
# Site: SNOTEL_BEAVER_PASS, Done before
# Site: SNOTEL_BEN_LOMOND_PEAK, Done before
# Site: SNOTEL_BEN_LOMOND_TRAIL, Done before
# Site: SNOTEL_BERRY_CREEK, Done before
# Site: SNOTEL_BERTHOUD_SUMMIT, Done before
# Site: SNOTEL_Bevans_Cabin, Done before
# Site: SNOTEL_BIG_BEND, Done before
# Site: SNOTEL_BIG_CREEK_SUM, Done before
# Site: SNOTEL_BIG_FLAT, Done before
# Site: SNOTEL_BIG_MEADOW, Done before
# Site: SNOTEL_BIG_SANDY_OPENING, Done before
# Site: SNOTEL_BILLIE_CREEK_DIVIDE, Done before
# Site: SNOTEL_BIRD_CREEK, Done before
# Site: SNOTEL_BLACK_FLAT-U.M._CK, Done before
# Site: SNOTEL_BLACKHALL_MTN, Done before
# Site: SNOTEL_Black_Mesa, Done before
# Site: SNOTEL_BLACKS_FORK_JCT, Done before
# Site: SNOTEL_BLUE_LAKES, Done before
# Site: SNOTEL_BOGUS_BASIN, Done before
# Site: SNOTEL_BOURNE, Done before
# Site: SNOTEL_BOX_CREEK, Done before
# Site: SNOTEL_BRIAN_HEAD, Done before
# Site: SNOTEL_BRIGHTON, Done before
# Site: SNOTEL_BRISTLECONE_TRAIL, Done before
# Site: SNOTEL_BROWN_DUCK, Done before
# Site: SNOTEL_BROWN_TOP, Done before
# Site: SNOTEL_BRUMLEY, Done before
# Site: SNOTEL_BUCKBOARD_FLAT, Done before
# Site: SNOTEL_BUCK_FLAT, Done before
# Site: SNOTEL_BUCKINGHORSE, Done before
# Site: SNOTEL_BUCK_PASTURE, Done before
# Site: SNOTEL_BUCKSKIN_JOE, Done before
# Site: SNOTEL_BUCKSKIN_LOWER, Done before
# Site: SNOTEL_BUG_LAKE, Done before
# Site: SNOTEL_BURNSIDE_LAKE, Done before
# Site: SNOTEL_BURNT_MOUNTAIN, Done before
# Site: SNOTEL_BURRO_MOUNTAIN, Done before
# Site: SNOTEL_BURTS_MILLER_RANCH, Done before
# Site: SNOTEL_BUTTE, Done before
# Site: SNOTEL_CAMP_JACKSON, Done before
# Site: SNOTEL_CARSON_PASS, Done before
# Site: SNOTEL_CASCADE_#2, Done before
# Site: SNOTEL_CASCADE_MOUNTAIN, Done before
# Site: SNOTEL_CASTLE_VALLEY, Done before
# Site: SNOTEL_CAVE_MOUNTAIN, Done before
# Site: SNOTEL_CAYUSE_PASS, Done before
# Site: SNOTEL_Chalender, Done before
# Site: SNOTEL_CHALK_CREEK_#1, Done before
# Site: SNOTEL_CHALK_CREEK_#2, Done before
# Site: SNOTEL_CHEMULT_ALTERNATE, Done before
# Site: SNOTEL_CHEPETA, Done before
# Site: SNOTEL_CHOCOLATE_GULCH, Done before
# Site: SNOTEL_CINNABAR_PARK, Done before
# Site: SNOTEL_CLACKAMAS_LAKE, Done before
# Site: SNOTEL_CLAYTON_SPRINGS, Done before
# Site: SNOTEL_CLEAR_CREEK_#1, Done before
# Site: SNOTEL_CLEAR_CREEK_#2, Done before
# Site: SNOTEL_CLEAR_LAKE, Done before
# Site: SNOTEL_COCHETOPA_PASS, Done before
# Site: SNOTEL_Columbia_Basin, Done before
# Site: SNOTEL_Copper_Mountain, Done before
# Site: SNOTEL_Corduroy_Flat, Done before
# Site: SNOTEL_Corral, Done before
# Site: SNOTEL_CORRAL_CANYON, Done before
# Site: SNOTEL_CRAB_CREEK, Done before
# Site: SNOTEL_CRATER_MEADOWS, Done before
# Site: SNOTEL_CROW_CREEK, Done before
# Site: SNOTEL_CSS_LAB, Done before
# Site: SNOTEL_CULEBRA_#2, Done before
# Site: SNOTEL_CURRANT_CREEK, Done before
# Site: SNOTEL_DANIELS-STRAWBERRY, Done before
# Site: SNOTEL_Defiance_Mines, Done before
# Site: SNOTEL_DIAMOND_PEAK, Done before
# Site: SNOTEL_DILLS_CAMP, Done before
# Site: SNOTEL_DISASTER_PEAK, Done before
# Site: SNOTEL_Dollarhide_Summit, Done before
# Site: SNOTEL_DONKEY_RESERVOIR, Done before
# Site: SNOTEL_DORSEY_BASIN, Done before
# Site: SNOTEL_DRAW_CREEK, Done before
# Site: SNOTEL_DRY_BREAD_POND, Done before
# Site: SNOTEL_Dry_Creek, Done before
# Site: SNOTEL_DRY_FORK, Done before
# Site: SNOTEL_DRY_LAKE, Done before
# Site: SNOTEL_EAST_RIM_DIVIDE, Done before
# Site: SNOTEL_EAST_WILLOW_CREEK, Done before
# Site: SNOTEL_EBBETTS_PASS, Done before
# Site: SNOTEL_ECHO_PEAK, Done before
# Site: SNOTEL_EF_BLACKS_FORK_GS, Done before
# Site: SNOTEL_Elk_Cabin, Done before
# Site: SNOTEL_FALLEN_LEAF, Done before
# Site: SNOTEL_FARMINGTON, Done before
# Site: SNOTEL_FARMINGTON_LOWER, Done before
# Site: SNOTEL_FARNSWORTH_LAKE, Done before
# Site: SNOTEL_FAWN_CREEK, Done before
# Site: SNOTEL_FISH_LAKE_UTAH, Done before
# Site: SNOTEL_FIVE_POINTS_LAKE, Done before
# Site: SNOTEL_FORESTDALE_CREEK, Done before
# Site: SNOTEL_FORT_VALLEY, Done before
# Site: SNOTEL_FRANKLIN_BASIN, Done before
# Site: SNOTEL_FREMONT_PASS, Done before
# Site: SNOTEL_Fry_Canyon, Done before
# Site: SNOTEL_GALENA_SUMMIT, Done before
# Site: SNOTEL_Gallegos_Peak, Done before
# Site: SNOTEL_GARDEN_CITY_SUMMIT, Done before
# Site: SNOTEL_GARDNER_PEAK, Done before
# Site: SNOTEL_GBRC_HQ, Done before
# Site: SNOTEL_GBRC_MEADOWS, Done before
# Site: SNOTEL_GEORGE_CREEK, Done before
# Site: SNOTEL_GIVEOUT, Done before
# Site: SNOTEL_GOLCONDA, Done before
# Site: SNOTEL_GOLD_AXE_CAMP, Done before
# Site: SNOTEL_GOOSEBERRY_R.S., Done before
# Site: SNOTEL_GOOSEBERRY_R.S._UP, Done before
# Site: SNOTEL_GRAND_TARGHEE, Done before
# Site: SNOTEL_Granite_Creek, Done before
# Site: SNOTEL_GRANITE_PEAK, Done before
# Site: SNOTEL_GREEN_MOUNTAIN, Done before
# Site: SNOTEL_GRIZZLY_PEAK, Done before
# Site: SNOTEL_Gunsight_Pass, Done before
# Site: SNOTEL_GUTZ_PEAK, Done before
# Site: SNOTEL_HAGANS_MEADOW, Done before
# Site: SNOTEL_HAPPY_JACK, Done before
# Site: SNOTEL_HARDSCRABBLE, Done before
# Site: SNOTEL_HARRIS_FLAT, Done before
# Site: SNOTEL_HARTS_PASS, Done before
# Site: SNOTEL_Hawley_Lake, Done before
# Site: SNOTEL_HAYDEN_FORK, Done before
# Site: SNOTEL_HEAVENLY_VALLEY, Done before
# Site: SNOTEL_HEWINTA, Done before
# Site: SNOTEL_HICKERSON_PARK, Done before
# Site: SNOTEL_HIGH_RIDGE, Done before
# Site: SNOTEL_HILTS_CREEK, Done before
# Site: SNOTEL_Hobble_Creek, Done before
# Site: SNOTEL_HOLE-IN-MOUNTAIN, Done before
# Site: SNOTEL_HOLE-IN-ROCK, Done before
# Site: SNOTEL_HOLLAND_MEADOWS, Done before
# Site: SNOTEL_HOOSIER_PASS, Done before
# Site: SNOTEL_Hopewell, Done before
# Site: SNOTEL_HORSE_MEADOW, Done before
# Site: SNOTEL_HORSE_RIDGE, Done before
# Site: SNOTEL_Huntington_Horse, Done before
# Site: SNOTEL_HYNDMAN, Done before
# Site: SNOTEL_INDEPENDENCE_CAMP, Done before
# Site: SNOTEL_INDEPENDENCE_CREEK, Done before
# Site: SNOTEL_INDEPENDENCE_LAKE, Done before
# Site: SNOTEL_INDIAN_CANYON, Done before
# Site: SNOTEL_INDIAN_ROCK, Done before
# Site: SNOTEL_JACK_CREEK_UPPER, Done before
# Site: SNOTEL_JACKSON_PEAK, Done before
# Site: SNOTEL_JACKS_PEAK, Done before
# Site: SNOTEL_JACKWHACKER_GULCH, Done before
# Site: SNOTEL_Jakes_Creek, Done before
# Site: SNOTEL_JONES_CORRAL, Done before
# Site: SNOTEL_KALAMAZOO, Done before
# Site: SNOTEL_KELLEY_R.S., Done before
# Site: SNOTEL_KILFOIL_CREEK, Done before
# Site: SNOTEL_KIMBERLY_MINE, Done before
# Site: SNOTEL_KINGS_CABIN, Done before
# Site: SNOTEL_KLONDIKE_NARROWS, Done before
# Site: SNOTEL_KOLOB, Done before
# Site: SNOTEL_LAKEFORK_#1, Done before
# Site: SNOTEL_LAKEFORK_#3, Done before
# Site: SNOTEL_Lakefork_Basin, Done before
# Site: SNOTEL_LAMANCE_CREEK, Done before
# Site: SNOTEL_LAMOILLE_#3, Done before
# Site: SNOTEL_LAPRELE_CREEK, Done before
# Site: SNOTEL_LARSEN_CREEK, Done before
# Site: SNOTEL_LASAL_MOUNTAIN, Done before
# Site: SNOTEL_LASAL_MOUNTAIN-LOWER, Done before
# Site: SNOTEL_LAUREL_DRAW, Done before
# Site: SNOTEL_LEAVITT_LAKE, Done before
# Site: SNOTEL_LEAVITT_MEADOWS, Done before
# Site: SNOTEL_LEE_CANYON, Done before
# Site: SNOTEL_LEWIS_LAKE_DIVIDE, Done before
# Site: SNOTEL_LEWIS_PEAK, Done before
# Site: SNOTEL_LIGHTNING_RIDGE, Done before
# Site: SNOTEL_LILY_LAKE, Done before
# Site: SNOTEL_LILY_POND, Done before
# Site: SNOTEL_LITTLE_BEAR, Done before
# Site: SNOTEL_LITTLE_GRASSY, Done before
# Site: SNOTEL_LITTLE_SNAKE_RIVER, Done before
# Site: SNOTEL_Little_Valley, Done before
# Site: SNOTEL_LIZARD_HEAD_PASS, Done before
# Site: SNOTEL_LOBDELL_LAKE, Done before
# Site: SNOTEL_LONE_CONE, Done before
# Site: SNOTEL_Lonesome_Beaver, Done before
# Site: SNOTEL_LONG_DRAW_RESV, Done before
# Site: SNOTEL_LONG_FLAT, Done before
# Site: SNOTEL_LONG_VALLEY, Done before
# Site: SNOTEL_LONG_VALLEY_JCT, Done before
# Site: SNOTEL_LOOKOUT, Done before
# Site: SNOTEL_LOOKOUT_PEAK, Done before
# Site: SNOTEL_LOST_CREEK_RESV, Done before
# Site: SNOTEL_LOST_DOG, Done before
# Site: SNOTEL_LOST_HORSE, Done before
# Site: SNOTEL_LOUIS_MEADOW, Done before
# Site: SNOTEL_MADISON_BUTTE, Done before
# Site: SNOTEL_MAGIC_MOUNTAIN, Done before
# Site: SNOTEL_MAMMOTH-COTTONWOOD, Done before
# Site: SNOTEL_MARLETTE_LAKE, Done before
# Site: SNOTEL_Marten_Ridge, Done before
# Site: SNOTEL_MEDANO_PASS, Done before
# Site: SNOTEL_Med_Bow, Done before
# Site: SNOTEL_MERCHANT_VALLEY, Done before
# Site: SNOTEL_Merritt_Mountain, Done before
# Site: SNOTEL_MF_Nooksack, Done before
# Site: SNOTEL_MICA_CREEK, Done before
# Site: SNOTEL_MICHIGAN_CREEK, Done before
# Site: SNOTEL_Midas, Done before
# Site: SNOTEL_MIDDLE_FORK_CAMP, Done before
# Site: SNOTEL_MIDWAY_VALLEY, Done before
# Site: SNOTEL_MILL-D_NORTH, Done before
# Site: SNOTEL_MILLER_WOODS, Done before
# Site: SNOTEL_MINING_FORK, Done before
# Site: SNOTEL_MONITOR_PASS, Done before
# Site: SNOTEL_MONTE_CRISTO, Done before
# Site: SNOTEL_Mormon_Mountain, Done before
# Site: SNOTEL_MORMON_MTN_SUMMIT, Done before
# Site: SNOTEL_MOSBY_MTN., Done before
# Site: SNOTEL_MOSCOW_MOUNTAIN, Done before
# Site: SNOTEL_MOSES_MTN, Done before
# Site: SNOTEL_MOSQUITO_RIDGE, Done before
# Site: SNOTEL_MOSS_SPRINGS, Done before
# Site: SNOTEL_MT._HOWARD, Done before
# Site: SNOTEL_MT_Baldy, Done before
# Site: SNOTEL_Mt_Pennell, Done before
# Site: SNOTEL_MT_ROSE_SKI_AREA, Done before
# Site: SNOTEL_MUD_FLAT, Done before
# Site: SNOTEL_MYRTLE_CREEK, Done before
# Site: SNOTEL_NAVAJO_WHISKEY_CK, Done before
# Site: SNOTEL_OAK_CREEK, Done before
# Site: SNOTEL_PALO, Done before
# Site: SNOTEL_Panguitch_Lake_RS, Done before
# Site: SNOTEL_PARADISE, Done before
# Site: SNOTEL_PARK_CONE, Done before
# Site: SNOTEL_PARK_CREEK_RIDGE, Done before
# Site: SNOTEL_PARK_RESERVOIR, Done before
# Site: SNOTEL_PARLEYS_SUMMIT, Done before
# Site: SNOTEL_PARRISH_CREEK, Done before
# Site: SNOTEL_PAYSON_R.S., Done before
# Site: SNOTEL_PHANTOM_VALLEY, Done before
# Site: SNOTEL_PICKLE_KEG, Done before
# Site: SNOTEL_PIERCE_R.S., Done before
# Site: SNOTEL_PINE_CREEK, Done before
# Site: SNOTEL_POCKET_CREEK, Done before
# Site: SNOTEL_POISON_FLAT, Done before
# Site: SNOTEL_Pole_Canyon, Done before
# Site: SNOTEL_POLE_CREEK_R.S., Done before
# Site: SNOTEL_PORPHYRY_CREEK, Done before
# Site: SNOTEL_QUARTZ_MOUNTAIN, Done before
# Site: SNOTEL_QUARTZ_PEAK, Done before
# Site: SNOTEL_Quemazon, Done before
# Site: SNOTEL_RAGGED_MOUNTAIN, Done before
# Site: SNOTEL_RAINBOW_CANYON, Done before
# Site: SNOTEL_RAINY_PASS, Done before
# Site: SNOTEL_Redden_Mine_Lwr, Done before
# Site: SNOTEL_RED_PINE_RIDGE, Done before
# Site: SNOTEL_RED_RIVER_PASS_#2, Done before
# Site: SNOTEL_Rees_Flat, Done before
# Site: SNOTEL_REYNOLDS_CREEK, Done before
# Site: SNOTEL_Rio_Santa_Barbara, Done before
# Site: SNOTEL_ROCK_CREEK, Done before
# Site: SNOTEL_ROCK_SPRINGS, Done before
# Site: SNOTEL_ROCKY_BASIN-SETTLEME, Done before
# Site: SNOTEL_ROUGH_AND_TUMBLE, Done before
# Site: SNOTEL_RUBICON_#2, Done before
# Site: SNOTEL_SAGE_CREEK_BASIN, Done before
# Site: SNOTEL_SALMON_MEADOWS, Done before
# Site: SNOTEL_SALT_CREEK_FALLS, Done before
# Site: SNOTEL_SALT_RIVER_SUMMIT, Done before
# Site: SNOTEL_Santa_Fe, Done before
# Site: SNOTEL_SASSE_RIDGE, Done before
# Site: SNOTEL_SAVAGE_PASS, Done before
# Site: SNOTEL_Sawtooth, Done before
# Site: SNOTEL_SCHNEIDER_MEADOWS, Done before
# Site: SNOTEL_SCHOFIELD_PASS, Done before
# Site: SNOTEL_SEELEY_CREEK, Done before
# Site: SNOTEL_Senorita_Divide_#2, Done before
# Site: SNOTEL_SEVENTYSIX_CREEK, Done before
# Site: SNOTEL_SHANGHI_SUMMIT, Done before
# Site: SNOTEL_SHARKSTOOTH, Done before
# Site: SNOTEL_SHEEP_MTN., Done before
# Site: SNOTEL_Sherwin, Done before
# Site: SNOTEL_SHUREE, Done before
# Site: SNOTEL_SIERRA_BLANCA, Done before
# Site: SNOTEL_SILVER_CREEK, Done before
# Site: SNOTEL_Silver_Creek_Nv, Done before
# Extracting data for site: SNOTEL_SILVIES
# Extracting data for site: SNOTEL_SLUMGULLION
# Extracting data for site: SNOTEL_SMILEY_MOUNTAIN
# Extracting data for site: SNOTEL_SMITH_and_MOREHOUSE
# Extracting data for site: SNOTEL_SNAKE_RIVER_STATION
# Extracting data for site: SNOTEL_SNOWBIRD
# Extracting data for site: SNOTEL_SNOW_MOUNTAIN
# Extracting data for site: SNOTEL_Snowstorm_Mtn
# Extracting data for site: SNOTEL_SOMSEN_RANCH
# Extracting data for site: SNOTEL_SONORA_PASS
# Extracting data for site: SNOTEL_SOURDOUGH_GULCH
# Extracting data for site: SNOTEL_SOUTH_MTN.
# Extracting data for site: SNOTEL_SPIRIT_LK
# Extracting data for site: SNOTEL_SPRATT_CREEK
# Extracting data for site: SNOTEL_SQUAW_SPRINGS
# Extracting data for site: SNOTEL_SQUAW_VALLEY_G.C.
# Extracting data for site: SNOTEL_Stag_Mountain
# Extracting data for site: SNOTEL_State_Line
# Extracting data for site: SNOTEL_STEEL_CREEK_PARK
# Extracting data for site: SNOTEL_STRAWBERRY_DIVIDE
# Extracting data for site: SNOTEL_SUCKER_CREEK
# Extracting data for site: SNOTEL_SUMMIT_LK
# Extracting data for site: SNOTEL_SUMMIT_MEADOW
# Extracting data for site: SNOTEL_SUMMIT_RANCH
# Extracting data for site: SNOTEL_Sunflower_Flat
# Extracting data for site: SNOTEL_Suu_Ranch
# Extracting data for site: SNOTEL_SWEDE_PEAK
# Extracting data for site: SNOTEL_TAHOE_CITY_CROSS
# Extracting data for site: SNOTEL_Takka_Wiiya
# Extracting data for site: SNOTEL_TAOS_POWDERHORN
# Extracting data for site: SNOTEL_TAYLOR_BUTTE
# Extracting data for site: SNOTEL_TAYLOR_CANYON
# Extracting data for site: SNOTEL_TEMPLE_FORK
# Extracting data for site: SNOTEL_Tent_Mtn_Lower
# Extracting data for site: SNOTEL_THAYNES_CANYON
# Extracting data for site: SNOTEL_Thistle_Flat
# Extracting data for site: SNOTEL_Thumb_Divide
# Extracting data for site: SNOTEL_TIMBERLINE
# Extracting data for site: SNOTEL_TIMPANOGOS_DIVIDE
# Extracting data for site: SNOTEL_TIPTON
# Extracting data for site: SNOTEL_TOE_JAM
# Extracting data for site: SNOTEL_TOGWOTEE_PASS
# Extracting data for site: SNOTEL_TONY_GROVE_LAKE
# Extracting data for site: SNOTEL_TONY_GROVE_RS
# Extracting data for site: SNOTEL_TOUCHET
# Extracting data for site: SNOTEL_Tres_Ritos
# Extracting data for site: SNOTEL_TRIAL_LAKE
# Extracting data for site: SNOTEL_TROUGH
# Extracting data for site: SNOTEL_TROUT_CREEK
# Extracting data for site: SNOTEL_TRUCKEE_#2
# Extracting data for site: SNOTEL_Upper_Joes_Valley
# Extracting data for site: SNOTEL_UPPER_RIO_GRANDE
# Extracting data for site: SNOTEL_UPPER_SAN_JUAN
# Extracting data for site: SNOTEL_UPPER_TAYLOR
# Extracting data for site: SNOTEL_USU_DOC_DANIEL
# Extracting data for site: SNOTEL_VACARRO_SPRING
# Extracting data for site: SNOTEL_Vacas_Locas
# Extracting data for site: SNOTEL_VAN_WYCK
# Extracting data for site: SNOTEL_VERNON_CREEK
# Extracting data for site: SNOTEL_VIRGINIA_LAKES_RIDGE
# Extracting data for site: SNOTEL_WARD_CREEK_#3
# Extracting data for site: SNOTEL_WARD_MOUNTAIN
# Site: SNOTEL_WATERHOLE, Done before
# Extracting data for site: SNOTEL_WEBSTER_FLAT
# Extracting data for site: SNOTEL_WESNER_SPRINGS
# Extracting data for site: SNOTEL_WHEELER_PEAK
# Extracting data for site: SNOTEL_WHISKEY_CK
# Extracting data for site: SNOTEL_WHITE_HORSE_LAKE
# Extracting data for site: SNOTEL_WHITE_RIVER_#1
# Extracting data for site: SNOTEL_White_River_Nv
# Extracting data for site: SNOTEL_WIDTSOE_#3
# Extracting data for site: SNOTEL_WILD_BASIN
# Extracting data for site: SNOTEL_WILDHORSE_DIVIDE
# Extracting data for site: SNOTEL_WILSON_CREEK
# Extracting data for site: SNOTEL_WINDY_PEAK
# Extracting data for site: SNOTEL_WOLF_CREEK_SUMMIT
# Extracting data for site: SNOTEL_Wrigley_Creek
# Extracting data for site: SNOTEL_Yankee_Reservoir
# Extracting data for site: SNOTEL_ZIRKEL
# Site: SOILSCAPE_node101, Done before
# Site: SOILSCAPE_node1017, Done before
# Site: SOILSCAPE_node1018, Done before
# Site: SOILSCAPE_node1019, Done before
# Site: SOILSCAPE_node102, Done before
# Site: SOILSCAPE_node1020, Done before
# Site: SOILSCAPE_node1021, Done before
# Site: SOILSCAPE_node1022, Done before
# Site: SOILSCAPE_node1023, Done before
# Site: SOILSCAPE_node1025, Done before
# Site: SOILSCAPE_node1027, Done before
# Site: SOILSCAPE_node1028, Done before
# Site: SOILSCAPE_node1029, Done before
# Site: SOILSCAPE_node103, Done before
# Site: SOILSCAPE_node1030, Done before
# Site: SOILSCAPE_node1031, Done before
# Site: SOILSCAPE_node105, Done before
# Site: SOILSCAPE_node106, Done before
# Site: SOILSCAPE_node107, Done before
# Site: SOILSCAPE_node108, Done before
# Site: SOILSCAPE_node111, Done before
# Site: SOILSCAPE_node112, Done before
# Site: SOILSCAPE_node114, Done before
# Site: SOILSCAPE_node115, Done before
# Site: SOILSCAPE_node116, Done before
# Site: SOILSCAPE_node119, Done before
# Site: SOILSCAPE_node120, Done before
# Site: SOILSCAPE_node1201, Done before
# Site: SOILSCAPE_node1202, Done before
# Site: SOILSCAPE_node1205, Done before
# Site: SOILSCAPE_node1206, Done before
# Site: SOILSCAPE_node121, Done before
# Site: SOILSCAPE_node1400, Done before
# Site: SOILSCAPE_node1401, Done before
# Site: SOILSCAPE_node1402, Done before
# Site: SOILSCAPE_node1403, Done before
# Site: SOILSCAPE_node1404, Done before
# Site: SOILSCAPE_node1405, Done before
# Site: SOILSCAPE_node1406, Done before
# Site: SOILSCAPE_node1407, Done before
# Site: SOILSCAPE_node1408, Done before
# Site: SOILSCAPE_node1409, Done before
# Site: SOILSCAPE_node1500, Done before
# Site: SOILSCAPE_node1501, Done before
# Site: SOILSCAPE_node1502, Done before
# Site: SOILSCAPE_node1503, Done before
# Site: SOILSCAPE_node1504, Done before
# Site: SOILSCAPE_node1505, Done before
# Site: SOILSCAPE_node1506, Done before
# Site: SOILSCAPE_node1507, Done before
# Site: SOILSCAPE_node401, Done before
# Site: SOILSCAPE_node403, Done before
# Site: SOILSCAPE_node404, Done before
# Site: SOILSCAPE_node405, Done before
# Site: SOILSCAPE_node406, Done before
# Site: SOILSCAPE_node408, Done before
# Site: SOILSCAPE_node410, Done before
# Site: SOILSCAPE_node412, Done before
# Site: SOILSCAPE_node413, Done before
# Site: SOILSCAPE_node414, Done before
# Site: SOILSCAPE_node415, Done before
# Site: SOILSCAPE_node416, Done before
# Site: SOILSCAPE_node417, Done before
# Site: SOILSCAPE_node418, Done before
# Site: SOILSCAPE_node419, Done before
# Site: SOILSCAPE_node420, Done before
# Site: SOILSCAPE_node501, Done before
# Site: SOILSCAPE_node503, Done before
# Site: SOILSCAPE_node504, Done before
# Site: SOILSCAPE_node505, Done before
# Site: SOILSCAPE_node506, Done before
# Site: SOILSCAPE_node508, Done before
# Site: SOILSCAPE_node509, Done before
# Site: SOILSCAPE_node510, Done before
# Site: SOILSCAPE_node511, Done before
# Site: SOILSCAPE_node512, Done before
# Site: SOILSCAPE_node513, Done before
# Site: SOILSCAPE_node514, Done before
# Site: SOILSCAPE_node515, Done before
# Site: SOILSCAPE_node518, Done before
# Site: SOILSCAPE_node701, Done before
# Site: SOILSCAPE_node704, Done before
# Site: SOILSCAPE_node708, Done before
# Site: SOILSCAPE_node709, Done before
# Site: SOILSCAPE_node710, Done before
# Site: SOILSCAPE_node712, Done before
# Site: SOILSCAPE_node713, Done before
# Site: SOILSCAPE_node900, Done before
# Site: SOILSCAPE_node901, Done before
# Site: SOILSCAPE_node902, Done before
# Site: SOILSCAPE_node903, Done before
# Site: SOILSCAPE_node904, Done before
# Site: SOILSCAPE_node905, Done before
# Site: SOILSCAPE_node906, Done before
# Site: SOILSCAPE_node907, Done before
# Site: SOILSCAPE_node908, Done before
# Site: SOILSCAPE_node909, Done before
# Site: SOILSCAPE_node911, Done before
# Site: SOILSCAPE_node912, Done before
# Site: SOILSCAPE_node913, Done before
# Site: SOILSCAPE_node914, Done before
# Site: SOILSCAPE_node915, Done before
# Site: SOILSCAPE_node916, Done before
# Site: USCRN_Aberdeen_35_WNW, Done before
# Site: USCRN_Arco_17_SW, Done before
# Site: USCRN_Asheville_13_S, Done before
# Site: USCRN_Asheville_8_SSW, Done before
# Site: USCRN_Austin_33_NW, Done before
# Site: USCRN_Avondale_2_N, Done before
# Site: USCRN_Baker_5_W, Done before
# Site: USCRN_Batesville_8_WNW, Done before
# Site: USCRN_Bedford_5_WNW, Done before
# Site: USCRN_Blackville_3_W, Done before
# Site: USCRN_Bodega_6_WSW, Done before
# Site: USCRN_Boulder_14_W, Done before
# Site: USCRN_Bowling_Green_21_NNE, Done before
# Site: USCRN_Brigham_City_28_WNW, Done before
# Site: USCRN_Bronte_11_NNE, Done before
# Site: USCRN_Brunswick_23_S, Done before
# Site: USCRN_Buffalo_13_ESE, Done before
# Site: USCRN_Cape_Charles_5_ENE, Done before
# Site: USCRN_Champaign_9_SW, Done before
# Site: USCRN_Charlottesville_2_SSE, Done before
# Site: USCRN_Chatham_1_SE, Done before
# Site: USCRN_Chillicothe_22_ENE, Done before
# Site: USCRN_Cortez_8_SE, Done before
# Site: USCRN_Corvallis_10_SSW, Done before
# Site: USCRN_Coshocton_8_NNE, Done before
# Site: USCRN_Crossville_7_NW, Done before
# Site: USCRN_Darrington_21_NNE, Done before
# Site: USCRN_Denio_52_WSW, Done before
# Site: USCRN_Des_Moines_17_E, Done before
# Site: USCRN_Dillon_18_WSW, Done before
# Site: USCRN_Dinosaur_2_E, Done before
# Site: USCRN_Durham_11_W, Done before
# Site: USCRN_Durham_2_N, Done before
# Site: USCRN_Durham_2_SSW, Done before
# Site: USCRN_Edinburg_17_NNE, Done before
# Site: USCRN_Elgin_5_S, Done before
# Site: USCRN_Elkins_21_ENE, Done before
# Site: USCRN_Everglades_City_5_NE, Done before
# Site: USCRN_Fairhope_3_NE, Done before
# Site: USCRN_Fallbrook_5_NE, Done before
# Site: USCRN_Gadsden_19_N, Done before
# Site: USCRN_Gaylord_9_SSW, Done before
# Site: USCRN_Goodridge_12_NNW, Done before
# Site: USCRN_Goodwell_2_E, Done before
# Site: USCRN_Goodwell_2_SE, Done before
# Site: USCRN_Harrison_20_SSE, Done before
# Site: USCRN_Holly_Springs_4_N, Done before
# Site: USCRN_Ithaca_13_E, Done before
# Site: USCRN_Jamestown_38_WSW, Done before
# Site: USCRN_John_Day_35_WNW, Done before
# Site: USCRN_Joplin_24_N, Done before
# Site: USCRN_Kingston_1_NW, Done before
# Site: USCRN_Kingston_1_W, Done before
# Site: USCRN_La_Junta_17_WSW, Done before
# Site: USCRN_Lafayette_13_SE, Done before
# Site: USCRN_Lander_11_SSE, Done before
# Site: USCRN_Las_Cruces_20_N, Done before
# Site: USCRN_Lewistown_42_WSW, Done before
# Site: USCRN_Limestone_4_NNW, Done before
# Site: USCRN_Lincoln_11_SW, Done before
# Site: USCRN_Lincoln_8_ENE, Done before
# Site: USCRN_Los_Alamos_13_W, Done before
# Site: USCRN_Manhattan_6_SSW, Done before
# Site: USCRN_McClellanville_7_NE, Done before
# Site: USCRN_Medora_7_E, Done before
# Site: USCRN_Merced_23_WSW, Done before
# Site: USCRN_Mercury_3_SSW, Done before
# Site: USCRN_Millbrook_3_W, Done before
# Site: USCRN_Monahans_6_ENE, Done before
# Site: USCRN_Monroe_26_N, Done before
# Site: USCRN_Montrose_11_ENE, Done before
# Site: USCRN_Moose_1_NNE, Done before
# Site: USCRN_Muleshoe_19_S, Done before
# Site: USCRN_Murphy_10_W, Done before
# Site: USCRN_Necedah_5_WNW, Done before
# Site: USCRN_Newton_11_SW, Done before
# Site: USCRN_Newton_5_ENE, Done before
# Site: USCRN_Newton_8_W, Done before
# Site: USCRN_Northgate_5_ESE, Done before
# Site: USCRN_Nunn_7_NNE, Done before
# Site: USCRN_Oakley_19_SSW, Done before
# Site: USCRN_Old_Town_2_W, Done before
# Site: USCRN_Palestine_6_WNW, Done before
# Site: USCRN_Panther_Junction_2_N, Done before
# Site: USCRN_Pierre_24_S, Done before
# Site: USCRN_Port_Aransas_32_NNE, Done before
# Site: USCRN_Quinault_4_NE, Done before
# Site: USCRN_Redding_12_WNW, Done before
# Site: USCRN_Riley_10_WSW, Done before
# Site: USCRN_Salem_10_W, Done before
# Site: USCRN_Sandstone_6_W, Done before
# Site: USCRN_Santa_Barbara_11_W, Done before
# Site: USCRN_Sebring_23_SSE, Done before
# Site: USCRN_Selma_13_WNW, Done before
# Site: USCRN_Shabbona_5_NNE, Done before
# Site: USCRN_Sioux_Falls_14_NNE, Done before
# Site: USCRN_Socorro_20_N, Done before
# Site: USCRN_Spokane_17_SSW, Done before
# Site: USCRN_St._Mary_1_SSW, Done before
# Site: USCRN_Stillwater_2_W, Done before
# Site: USCRN_Stillwater_5_WNW, Done before
# Site: USCRN_Stovepipe_Wells_1_SW, Done before
# Site: USCRN_Sundance_8_NNW, Done before
# Site: USCRN_Titusville_7_E, Done before
# Site: USCRN_Tucson_11_W, Done before
# Site: USCRN_Versailles_3_NNW, Done before
# Site: USCRN_Watkinsville_5_SSE, Done before
# Site: USCRN_Whitman_5_ENE, Done before
# Site: USCRN_Williams_35_NNW, Done before
# Site: USCRN_Wolf_Point_29_ENE, Done before
# Site: USCRN_Wolf_Point_34_NE, Done before
# Site: USCRN_Yosemite_Village_12_W, Done before
# Site: USCRN_Yuma_27_ENE, Done before

# %% [markdown]
# ## remove sites without ground soil moisture measurements
