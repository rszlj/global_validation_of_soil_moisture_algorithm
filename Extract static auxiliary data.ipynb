# %% [markdown]
# # Extract static auxiliary data for each site
#
# ## This notebook only extract the landcover type of each site across 2016-2019
# ## It can be easily extended to include others from GEE database e.g., DEM, slope

# %% [markdown]
# Setup

# %%
import os
import pandas as pd
import numpy as np
import ee
import utils
os.environ['HTTP_PROXY'] = 'http://127.0.0.1:41091'
os.environ['HTTPS_PROXY'] = 'http://127.0.0.1:41091'
ee.Initialize()
START_DATE = "2016-01-01"
END_DATE = "2019-12-31"  # 
HOME_DIR = r"E:\Zoho WorkDrive (YICODE)\My Folders\TimeSeriesRetrieval\Extension"
SM_SITES = os.path.join(HOME_DIR, "site_info.csv") # the site informaiton extracted by Preprocessing_ISMN_Raw_Data.ipynb

# %% [markdown]
# Read the sites information

# %%
sites = pd.read_csv(SM_SITES, float_precision="high")

# %% [markdown]
# Extract the landcover types and save as 4 columns '2016','2017','2018','2019' in the site_info.csv

# %%
PRODUCT = "COPERNICUS/Landcover/100m/Proba-V-C3/Global"
BANDS = ['discrete_classification']
BUFFER = 0 # buffer was not applied as the resolution of LULC is 100m, being similar to applying a nearest resampling
df= pd.DataFrame(columns={'2016','2017','2018','2019'})
if '2016' not in sites: # LULC is extracted if it's not in the site_info.csv 
#    site_geometry = ee.Geometry.Point(site.lon, site.lat).buffer(BUFFER)
    for site_idx, site in sites.iterrows():
        print(f'Extracting the LULC for site: {site.network}_{site.station}')
        site_geometry = ee.Geometry.Point(site.lon, site.lat)
        imCol = ee.ImageCollection(PRODUCT).filterDate(START_DATE, END_DATE).select(BANDS)
        image_info = imCol.first().getInfo()
        crs=image_info['bands'][0]['crs']
        scale=abs(image_info['bands'][0]['crs_transform'][0])
        data=imCol.getRegion(site_geometry,scale,crs).getInfo()
        data_df = pd.DataFrame(data[1:], columns=data[0])
        data_df=data_df.set_index('id').T.iloc[3:]
        df=df.append(data_df)
df.index=sites.index
sites=pd.concat([sites,df[['2016','2017','2018','2019']]], axis=1)
sites=sites.rename({'2016':'LC2016','2017':'LC2017','2018':'LC2018','2019':'LC2019'}, axis=1)
sites.to_csv(SM_SITES,index=False)
# Out:
# Extracting the LULC for site: AMMA-CATCH_Banizoumbou
# Extracting the LULC for site: AMMA-CATCH_Belefoungou-Mid
# Extracting the LULC for site: AMMA-CATCH_Belefoungou-Top
# Extracting the LULC for site: AMMA-CATCH_Nalohou-Mid
# Extracting the LULC for site: AMMA-CATCH_Nalohou-Top
# Extracting the LULC for site: AMMA-CATCH_Tondikiboro
# Extracting the LULC for site: AMMA-CATCH_Wankama
# Extracting the LULC for site: PBO_H2O_Bethlehem
# Extracting the LULC for site: PBO_H2O_Mafikeng
# Extracting the LULC for site: PBO_H2O_Newcastle
# Extracting the LULC for site: PBO_H2O_Sutherland
# Extracting the LULC for site: PBO_H2O_Upington
# Extracting the LULC for site: SD_DEM_Demokeya
# Extracting the LULC for site: TAHMO_CRIG_(Soil_Moisture_Station_1)
# Extracting the LULC for site: TAHMO_CRIG_(Soil_Moisture_Station_2)
# Extracting the LULC for site: TAHMO_CSIR-SARI,_Nyankpala_-_Tamale
# Extracting the LULC for site: TAHMO_KNUST_Farm,_Kumasi
# Extracting the LULC for site: CTP_SMTMN_L01
# Extracting the LULC for site: CTP_SMTMN_L02
# Extracting the LULC for site: CTP_SMTMN_L03
# Extracting the LULC for site: CTP_SMTMN_L04_M02
# Extracting the LULC for site: CTP_SMTMN_L05_M06
# Extracting the LULC for site: CTP_SMTMN_L06_M10
# Extracting the LULC for site: CTP_SMTMN_L07_M13
# Extracting the LULC for site: CTP_SMTMN_L08_M14
# Extracting the LULC for site: CTP_SMTMN_L09_M16
# Extracting the LULC for site: CTP_SMTMN_L10_M17
# Extracting the LULC for site: CTP_SMTMN_L11_M21
# Extracting the LULC for site: CTP_SMTMN_L12_M22
# Extracting the LULC for site: CTP_SMTMN_L13
# Extracting the LULC for site: CTP_SMTMN_L14
# Extracting the LULC for site: CTP_SMTMN_L15
# Extracting the LULC for site: CTP_SMTMN_L16
# Extracting the LULC for site: CTP_SMTMN_L17
# Extracting the LULC for site: CTP_SMTMN_L18
# Extracting the LULC for site: CTP_SMTMN_L19
# Extracting the LULC for site: CTP_SMTMN_L20
# Extracting the LULC for site: CTP_SMTMN_L21
# Extracting the LULC for site: CTP_SMTMN_L22
# Extracting the LULC for site: CTP_SMTMN_L23
# Extracting the LULC for site: CTP_SMTMN_L24
# Extracting the LULC for site: CTP_SMTMN_L26
# Extracting the LULC for site: CTP_SMTMN_L27
# Extracting the LULC for site: CTP_SMTMN_L29
# Extracting the LULC for site: CTP_SMTMN_L31
# Extracting the LULC for site: CTP_SMTMN_L32
# Extracting the LULC for site: CTP_SMTMN_L33
# Extracting the LULC for site: CTP_SMTMN_L34
# Extracting the LULC for site: CTP_SMTMN_L35
# Extracting the LULC for site: CTP_SMTMN_L36
# Extracting the LULC for site: CTP_SMTMN_L37
# Extracting the LULC for site: CTP_SMTMN_L38
# Extracting the LULC for site: CTP_SMTMN_M01
# Extracting the LULC for site: CTP_SMTMN_M03
# Extracting the LULC for site: CTP_SMTMN_M04
# Extracting the LULC for site: CTP_SMTMN_M05
# Extracting the LULC for site: CTP_SMTMN_M07_S01
# Extracting the LULC for site: CTP_SMTMN_M08
# Extracting the LULC for site: CTP_SMTMN_M11_S09
# Extracting the LULC for site: CTP_SMTMN_M12_S08
# Extracting the LULC for site: CTP_SMTMN_M15
# Extracting the LULC for site: CTP_SMTMN_M18
# Extracting the LULC for site: CTP_SMTMN_M19
# Extracting the LULC for site: CTP_SMTMN_M20
# Extracting the LULC for site: CTP_SMTMN_S02
# Extracting the LULC for site: CTP_SMTMN_S03
# Extracting the LULC for site: CTP_SMTMN_S04
# Extracting the LULC for site: CTP_SMTMN_S05
# Extracting the LULC for site: CTP_SMTMN_S06
# Extracting the LULC for site: CTP_SMTMN_S07
# Extracting the LULC for site: MAQU_CST_03
# Extracting the LULC for site: MAQU_CST_04
# Extracting the LULC for site: MAQU_CST_05
# Extracting the LULC for site: MAQU_NST_01
# Extracting the LULC for site: MAQU_NST_03
# Extracting the LULC for site: MAQU_NST_05
# Extracting the LULC for site: MAQU_NST_06
# Extracting the LULC for site: MAQU_NST_07
# Extracting the LULC for site: MAQU_NST_08
# Extracting the LULC for site: MAQU_NST_09
# Extracting the LULC for site: MAQU_NST_10
# Extracting the LULC for site: MAQU_NST_24
# Extracting the LULC for site: MAQU_NST_25
# Extracting the LULC for site: MAQU_NST_30
# Extracting the LULC for site: MAQU_NST_31
# Extracting the LULC for site: MAQU_NST_32
# Extracting the LULC for site: NAQU_NQ01
# Extracting the LULC for site: NAQU_NQ02
# Extracting the LULC for site: NAQU_NQ03
# Extracting the LULC for site: NAQU_NQ04
# Extracting the LULC for site: NAQU_NQ_BJ
# Extracting the LULC for site: NAQU_NQ_Kema
# Extracting the LULC for site: NAQU_NQ_MS
# Extracting the LULC for site: NAQU_NQ_North
# Extracting the LULC for site: NAQU_NQ_West
# Extracting the LULC for site: NGARI_ALI01
# Extracting the LULC for site: NGARI_ALI02
# Extracting the LULC for site: NGARI_ALI03
# Extracting the LULC for site: NGARI_SQ01
# Extracting the LULC for site: NGARI_SQ02
# Extracting the LULC for site: NGARI_SQ03
# Extracting the LULC for site: NGARI_SQ06
# Extracting the LULC for site: NGARI_SQ07
# Extracting the LULC for site: NGARI_SQ08
# Extracting the LULC for site: NGARI_SQ10
# Extracting the LULC for site: NGARI_SQ11
# Extracting the LULC for site: NGARI_SQ14
# Extracting the LULC for site: NGARI_SQ17
# Extracting the LULC for site: NGARI_SQ18
# Extracting the LULC for site: NGARI_SQ19
# Extracting the LULC for site: NGARI_SQ20
# Extracting the LULC for site: NGARI_SQ21
# Extracting the LULC for site: OZNET_Alabama
# Extracting the LULC for site: OZNET_Banandra
# Extracting the LULC for site: OZNET_Bundure
# Extracting the LULC for site: OZNET_Cheverelis
# Extracting the LULC for site: OZNET_Cox
# Extracting the LULC for site: OZNET_Dry_Lake
# Extracting the LULC for site: OZNET_Eulo
# Extracting the LULC for site: OZNET_Evergreen
# Extracting the LULC for site: OZNET_Kyeamba_Mouth
# Extracting the LULC for site: OZNET_S_Coleambally
# Extracting the LULC for site: OZNET_Samarra
# Extracting the LULC for site: OZNET_Silver_Springs
# Extracting the LULC for site: OZNET_Spring_Bank
# Extracting the LULC for site: OZNET_Uri_Park
# Extracting the LULC for site: OZNET_Widgiewa
# Extracting the LULC for site: OZNET_Wollumbi
# Extracting the LULC for site: OZNET_Wynella
# Extracting the LULC for site: OZNET_Yamma_Road
# Extracting the LULC for site: OZNET_Yammacoona
# Extracting the LULC for site: SMN-SDR_L1
# Extracting the LULC for site: SMN-SDR_L10
# Extracting the LULC for site: SMN-SDR_L11
# Extracting the LULC for site: SMN-SDR_L12
# Extracting the LULC for site: SMN-SDR_L13
# Extracting the LULC for site: SMN-SDR_L14
# Extracting the LULC for site: SMN-SDR_L2
# Extracting the LULC for site: SMN-SDR_L3
# Extracting the LULC for site: SMN-SDR_L4
# Extracting the LULC for site: SMN-SDR_L5
# Extracting the LULC for site: SMN-SDR_L6
# Extracting the LULC for site: SMN-SDR_L7
# Extracting the LULC for site: SMN-SDR_L8
# Extracting the LULC for site: SMN-SDR_L9
# Extracting the LULC for site: SMN-SDR_M1
# Extracting the LULC for site: SMN-SDR_M10
# Extracting the LULC for site: SMN-SDR_M11
# Extracting the LULC for site: SMN-SDR_M12
# Extracting the LULC for site: SMN-SDR_M2
# Extracting the LULC for site: SMN-SDR_M3
# Extracting the LULC for site: SMN-SDR_M4
# Extracting the LULC for site: SMN-SDR_M5
# Extracting the LULC for site: SMN-SDR_M6
# Extracting the LULC for site: SMN-SDR_M7
# Extracting the LULC for site: SMN-SDR_M8
# Extracting the LULC for site: SMN-SDR_M9
# Extracting the LULC for site: SMN-SDR_S1
# Extracting the LULC for site: SMN-SDR_S2
# Extracting the LULC for site: SMN-SDR_S3
# Extracting the LULC for site: SMN-SDR_S4
# Extracting the LULC for site: SMN-SDR_S5
# Extracting the LULC for site: SMN-SDR_S6
# Extracting the LULC for site: SMN-SDR_S7
# Extracting the LULC for site: SMN-SDR_S8
# Extracting the LULC for site: BIEBRZA_S-1_grassland_soil_1
# Extracting the LULC for site: BIEBRZA_S-1_grassland_soil_2
# Extracting the LULC for site: BIEBRZA_S-1_grassland_soil_3
# Extracting the LULC for site: BIEBRZA_S-1_grassland_soil_4
# Extracting the LULC for site: BIEBRZA_S-1_grassland_soil_5
# Extracting the LULC for site: BIEBRZA_S-1_grassland_soil_6
# Extracting the LULC for site: BIEBRZA_S-1_grassland_soil_7
# Extracting the LULC for site: BIEBRZA_S-1_grassland_soil_8
# Extracting the LULC for site: BIEBRZA_S-1_grassland_soil_9
# Extracting the LULC for site: BIEBRZA_S-1_marshland_soil_11
# Extracting the LULC for site: BIEBRZA_S-1_marshland_soil_12
# Extracting the LULC for site: BIEBRZA_S-1_marshland_soil_13
# Extracting the LULC for site: BIEBRZA_S-1_marshland_soil_14
# Extracting the LULC for site: BIEBRZA_S-1_marshland_soil_15
# Extracting the LULC for site: BIEBRZA_S-1_marshland_soil_16
# Extracting the LULC for site: BIEBRZA_S-1_marshland_soil_17
# Extracting the LULC for site: BIEBRZA_S-1_marshland_soil_18
# Extracting the LULC for site: BIEBRZA_S-1_marshland_soil_19
# Extracting the LULC for site: FMI_SAA111
# Extracting the LULC for site: FMI_SAA112
# Extracting the LULC for site: FMI_SAA120
# Extracting the LULC for site: FMI_SOD011
# Extracting the LULC for site: FMI_SOD013
# Extracting the LULC for site: FMI_SOD021
# Extracting the LULC for site: FMI_SOD071
# Extracting the LULC for site: FMI_SOD072
# Extracting the LULC for site: FMI_SOD073
# Extracting the LULC for site: FMI_SOD081
# Extracting the LULC for site: FMI_SOD083
# Extracting the LULC for site: FMI_SOD091
# Extracting the LULC for site: FMI_SOD092
# Extracting the LULC for site: FMI_SOD093
# Extracting the LULC for site: FMI_SOD101
# Extracting the LULC for site: FMI_SOD102
# Extracting the LULC for site: FMI_SOD103
# Extracting the LULC for site: FMI_SOD130
# Extracting the LULC for site: FMI_SOD140
# Extracting the LULC for site: FMI_SODAWS
# Extracting the LULC for site: FR_Aqui_fraye
# Extracting the LULC for site: FR_Aqui_grandcal
# Extracting the LULC for site: FR_Aqui_hillan2
# Extracting the LULC for site: FR_Aqui_parcmeteo
# Extracting the LULC for site: HOAL_Hoal_01
# Extracting the LULC for site: HOAL_Hoal_02
# Extracting the LULC for site: HOAL_Hoal_04
# Extracting the LULC for site: HOAL_Hoal_05
# Extracting the LULC for site: HOAL_Hoal_06
# Extracting the LULC for site: HOAL_Hoal_07
# Extracting the LULC for site: HOAL_Hoal_08
# Extracting the LULC for site: HOAL_Hoal_09
# Extracting the LULC for site: HOAL_Hoal_10
# Extracting the LULC for site: HOAL_Hoal_11
# Extracting the LULC for site: HOAL_Hoal_12
# Extracting the LULC for site: HOAL_Hoal_13
# Extracting the LULC for site: HOAL_Hoal_14
# Extracting the LULC for site: HOAL_Hoal_15
# Extracting the LULC for site: HOAL_Hoal_16
# Extracting the LULC for site: HOAL_Hoal_17
# Extracting the LULC for site: HOAL_Hoal_18
# Extracting the LULC for site: HOAL_Hoal_19
# Extracting the LULC for site: HOAL_Hoal_21
# Extracting the LULC for site: HOAL_Hoal_22
# Extracting the LULC for site: HOAL_Hoal_24
# Extracting the LULC for site: HOAL_Hoal_25
# Extracting the LULC for site: HOAL_Hoal_26
# Extracting the LULC for site: HOAL_Hoal_27
# Extracting the LULC for site: HOAL_Hoal_28
# Extracting the LULC for site: HOAL_Hoal_29
# Extracting the LULC for site: HOAL_Hoal_30
# Extracting the LULC for site: HOAL_Hoal_32
# Extracting the LULC for site: HOAL_Hoal_33
# Extracting the LULC for site: HOAL_Hoal_34
# Extracting the LULC for site: HOAL_Hoal_35
# Extracting the LULC for site: HOAL_Hoal_36
# Extracting the LULC for site: HOBE_1.01
# Extracting the LULC for site: HOBE_1.02
# Extracting the LULC for site: HOBE_1.03
# Extracting the LULC for site: HOBE_1.04
# Extracting the LULC for site: HOBE_1.05
# Extracting the LULC for site: HOBE_1.06
# Extracting the LULC for site: HOBE_1.07
# Extracting the LULC for site: HOBE_1.08
# Extracting the LULC for site: HOBE_1.09
# Extracting the LULC for site: HOBE_1.1
# Extracting the LULC for site: HOBE_2.01
# Extracting the LULC for site: HOBE_2.03
# Extracting the LULC for site: HOBE_2.04
# Extracting the LULC for site: HOBE_2.05
# Extracting the LULC for site: HOBE_2.06b
# Extracting the LULC for site: HOBE_2.07
# Extracting the LULC for site: HOBE_2.08b
# Extracting the LULC for site: HOBE_2.09
# Extracting the LULC for site: HOBE_2.1
# Extracting the LULC for site: HOBE_2.11
# Extracting the LULC for site: HOBE_3.01
# Extracting the LULC for site: HOBE_3.02
# Extracting the LULC for site: HOBE_3.03
# Extracting the LULC for site: HOBE_3.04
# Extracting the LULC for site: HOBE_3.05
# Extracting the LULC for site: HOBE_3.06
# Extracting the LULC for site: HOBE_3.07
# Extracting the LULC for site: HOBE_3.08
# Extracting the LULC for site: HOBE_3.09
# Extracting the LULC for site: HYDROL-NET_PERUGIA_Water_Engineering_Experimental_Field_1
# Extracting the LULC for site: HYDROL-NET_PERUGIA_Water_Engineering_Experimental_Field_2
# Extracting the LULC for site: REMEDHUS_Canizal
# Extracting the LULC for site: REMEDHUS_Carretoro
# Extracting the LULC for site: REMEDHUS_Casa_Periles
# Extracting the LULC for site: REMEDHUS_Concejo_del_Monte
# Extracting the LULC for site: REMEDHUS_El_Coto
# Extracting the LULC for site: REMEDHUS_El_Tomillar
# Extracting the LULC for site: REMEDHUS_Granja_g
# Extracting the LULC for site: REMEDHUS_Guarrati
# Extracting the LULC for site: REMEDHUS_La_Atalaya
# Extracting the LULC for site: REMEDHUS_La_Cruz_de_Elias
# Extracting the LULC for site: REMEDHUS_Las_Arenas
# Extracting the LULC for site: REMEDHUS_Las_Bodegas
# Extracting the LULC for site: REMEDHUS_Las_Brozas
# Extracting the LULC for site: REMEDHUS_Las_Eritas
# Extracting the LULC for site: REMEDHUS_Las_Tres_Rayas
# Extracting the LULC for site: REMEDHUS_Las_Vacas
# Extracting the LULC for site: REMEDHUS_Las_Victorias
# Extracting the LULC for site: REMEDHUS_Llanos_de_la_Boveda
# Extracting the LULC for site: REMEDHUS_Paredinas
# Extracting the LULC for site: REMEDHUS_Zamarron
# Extracting the LULC for site: RSMN_Alexandria
# Extracting the LULC for site: RSMN_Bacles
# Extracting the LULC for site: RSMN_Banloc
# Extracting the LULC for site: RSMN_Barlad
# Extracting the LULC for site: RSMN_Calarasi
# Extracting the LULC for site: RSMN_Chisineu_Cris
# Extracting the LULC for site: RSMN_Corugea
# Extracting the LULC for site: RSMN_Cotnari
# Extracting the LULC for site: RSMN_Darabani
# Extracting the LULC for site: RSMN_Dej
# Extracting the LULC for site: RSMN_Dumbraveni
# Extracting the LULC for site: RSMN_Iasi
# Extracting the LULC for site: RSMN_Oradea
# Extracting the LULC for site: RSMN_Rosiorii_de_Vede
# Extracting the LULC for site: RSMN_Sannicolau_Mare
# Extracting the LULC for site: RSMN_Satu_Mare
# Extracting the LULC for site: RSMN_Slatina
# Extracting the LULC for site: RSMN_Slobozia
# Extracting the LULC for site: RSMN_Tecuci
# Extracting the LULC for site: Ru_CFR_Fyodorovskoye_dry_spruce_stand
# Extracting the LULC for site: Ru_CFR_Fyodorovskoye_wet_spruce_stand
# Extracting the LULC for site: SMOSMANIA_Barnas
# Extracting the LULC for site: SMOSMANIA_Berzeme
# Extracting the LULC for site: SMOSMANIA_Cabrieres_dAvignon
# Extracting the LULC for site: SMOSMANIA_Condom
# Extracting the LULC for site: SMOSMANIA_Creon_dArmagnac
# Extracting the LULC for site: SMOSMANIA_La_Grand_Combe
# Extracting the LULC for site: SMOSMANIA_Lahas
# Extracting the LULC for site: SMOSMANIA_Lezignan_Corbieres
# Extracting the LULC for site: SMOSMANIA_Mazan-Abbaye
# Extracting the LULC for site: SMOSMANIA_Mejannes-le-Clap
# Extracting the LULC for site: SMOSMANIA_Montaut
# Extracting the LULC for site: SMOSMANIA_Mouthoumet
# Extracting the LULC for site: SMOSMANIA_Narbonne
# Extracting the LULC for site: SMOSMANIA_Peyrusse_Grande
# Extracting the LULC for site: SMOSMANIA_Pezenas
# Extracting the LULC for site: SMOSMANIA_Pezenas_old
# Extracting the LULC for site: SMOSMANIA_Prades-le-Lez
# Extracting the LULC for site: SMOSMANIA_Sabres
# Extracting the LULC for site: SMOSMANIA_Saint_Felix_de_Lauragais
# Extracting the LULC for site: SMOSMANIA_Savenes
# Extracting the LULC for site: SMOSMANIA_Urgons
# Extracting the LULC for site: SMOSMANIA_Villevielle
# Extracting the LULC for site: TERENO_Gevenich
# Extracting the LULC for site: TERENO_Merzenhausen
# Extracting the LULC for site: TERENO_Schoeneseiffen
# Extracting the LULC for site: TERENO_Selhausen
# Extracting the LULC for site: TERENO_Wildenrath
# Extracting the LULC for site: WSMN_WSMN_1
# Extracting the LULC for site: WSMN_WSMN_2
# Extracting the LULC for site: WSMN_WSMN_3
# Extracting the LULC for site: WSMN_WSMN_4
# Extracting the LULC for site: ARM_Anthony
# Extracting the LULC for site: ARM_Ashton
# Extracting the LULC for site: ARM_Byron
# Extracting the LULC for site: ARM_Lamont_CF1
# Extracting the LULC for site: ARM_Maple_City
# Extracting the LULC for site: ARM_Marshall
# Extracting the LULC for site: ARM_Medford
# Extracting the LULC for site: ARM_Morrison
# Extracting the LULC for site: ARM_Newkirk
# Extracting the LULC for site: ARM_Omega
# Extracting the LULC for site: ARM_Pawhuska
# Extracting the LULC for site: ARM_Ringwood
# Extracting the LULC for site: ARM_Tryon
# Extracting the LULC for site: ARM_Tyro
# Extracting the LULC for site: ARM_Waukomis
# Extracting the LULC for site: FLUXNET-AMERIFLUX_Bouldin_Island_Alfalfa
# Extracting the LULC for site: FLUXNET-AMERIFLUX_Bouldin_Island_corn
# Extracting the LULC for site: FLUXNET-AMERIFLUX_Sherman_Barn
# Extracting the LULC for site: FLUXNET-AMERIFLUX_Tonzi_Ranch
# Extracting the LULC for site: FLUXNET-AMERIFLUX_Vaira_Ranch
# Extracting the LULC for site: iRON_Brush_Creek
# Extracting the LULC for site: iRON_Glassier_Ranch
# Extracting the LULC for site: iRON_Glenwood_Springs
# Extracting the LULC for site: iRON_Independence_Pass
# Extracting the LULC for site: iRON_Northstar_Aspen_Grove
# Extracting the LULC for site: iRON_Northstar_Transition_Zone
# Extracting the LULC for site: iRON_Sky_Mountain
# Extracting the LULC for site: iRON_Smuggler_Mountain
# Extracting the LULC for site: iRON_Spring_Valley
# Extracting the LULC for site: PBO_H2O_ALKALILAKE
# Extracting the LULC for site: PBO_H2O_ANGELFIRE
# Extracting the LULC for site: PBO_H2O_ANGUS_PROP
# Extracting the LULC for site: PBO_H2O_ANTIMONYFL
# Extracting the LULC for site: PBO_H2O_ARKANSACRK
# Extracting the LULC for site: PBO_H2O_ARMINGTON
# Extracting the LULC for site: PBO_H2O_ATOMICCITY
# Extracting the LULC for site: PBO_H2O_AUBREYPEAK
# Extracting the LULC for site: PBO_H2O_AVILARANCH
# Extracting the LULC for site: PBO_H2O_BAKERCITY
# Extracting the LULC for site: PBO_H2O_BANDONARPT
# Extracting the LULC for site: PBO_H2O_BILLINGSAP
# Extracting the LULC for site: PBO_H2O_BIRCHIMCYN
# Extracting the LULC for site: PBO_H2O_BITTERWATR
# Extracting the LULC for site: PBO_H2O_BKAP_SCGN
# Extracting the LULC for site: PBO_H2O_BLACKROCK
# Extracting the LULC for site: PBO_H2O_BLINDSPRIN
# Extracting the LULC for site: PBO_H2O_BROTHERSDT
# Extracting the LULC for site: PBO_H2O_BUCKLEYFLT
# Extracting the LULC for site: PBO_H2O_BUCKSKINMT
# Extracting the LULC for site: PBO_H2O_BUTTERBRED
# Extracting the LULC for site: PBO_H2O_BUZZARDRST
# Extracting the LULC for site: PBO_H2O_CABOROJO
# Extracting the LULC for site: PBO_H2O_CALAVERAS
# Extracting the LULC for site: PBO_H2O_CALCITYAPT
# Extracting the LULC for site: PBO_H2O_CALCITYPLR
# Extracting the LULC for site: PBO_H2O_CALIVALLEY
# Extracting the LULC for site: PBO_H2O_CAMPELLIOT
# Extracting the LULC for site: PBO_H2O_CARRIZORAN
# Extracting the LULC for site: PBO_H2O_CERREJON
# Extracting the LULC for site: PBO_H2O_CERRILLOS
# Extracting the LULC for site: PBO_H2O_CHILEOFLAT
# Extracting the LULC for site: PBO_H2O_CLAYTONARP
# Extracting the LULC for site: PBO_H2O_CN02
# Extracting the LULC for site: PBO_H2O_CN07
# Extracting the LULC for site: PBO_H2O_COXCOMBMTN
# Extracting the LULC for site: PBO_H2O_CRRS_SCGN
# Extracting the LULC for site: PBO_H2O_CSCI_SCGN
# Extracting the LULC for site: PBO_H2O_CTDM_SCGN
# Extracting the LULC for site: PBO_H2O_DELANO_AIR
# Extracting the LULC for site: PBO_H2O_DELTAMUNI
# Extracting the LULC for site: PBO_H2O_DELVALLE
# Extracting the LULC for site: PBO_H2O_DRI_RENO
# Extracting the LULC for site: PBO_H2O_DRYMOUNTAI
# Extracting the LULC for site: PBO_H2O_EcRockStPkTX2012
# Extracting the LULC for site: PBO_H2O_ENNISFISH
# Extracting the LULC for site: PBO_H2O_FALLBROOK
# Extracting the LULC for site: PBO_H2O_FGST_SCGN
# Extracting the LULC for site: PBO_H2O_FORDRA087G
# Extracting the LULC for site: PBO_H2O_FOUNTGREEN
# Extracting the LULC for site: PBO_H2O_FREEMONTAP
# Extracting the LULC for site: PBO_H2O_GLRS_SCGN
# Extracting the LULC for site: PBO_H2O_GNPS_SCGN
# Extracting the LULC for site: PBO_H2O_GRANITEMTN
# Extracting the LULC for site: PBO_H2O_GRANITEPK
# Extracting the LULC for site: PBO_H2O_GRANTS
# Extracting the LULC for site: PBO_H2O_GRAPEVINE
# Extracting the LULC for site: PBO_H2O_HARTMTNNWR
# Extracting the LULC for site: PBO_H2O_HAYSPEAK
# Extracting the LULC for site: PBO_H2O_HILL72
# Extracting the LULC for site: PBO_H2O_HILLMRANCHM
# Extracting the LULC for site: PBO_H2O_HLFISLPARK
# Extracting the LULC for site: PBO_H2O_HLFSTORYRN
# Extracting the LULC for site: PBO_H2O_HNSLVALLY
# Extracting the LULC for site: PBO_H2O_HORSHEAVEN
# Extracting the LULC for site: PBO_H2O_HUNT_SCGN
# Extracting the LULC for site: PBO_H2O_HVYS_SCGN
# Extracting the LULC for site: PBO_H2O_IMPERIALSP
# Extracting the LULC for site: PBO_H2O_IMPS_SCGN
# Extracting the LULC for site: PBO_H2O_INDIANPEAK
# Extracting the LULC for site: PBO_H2O_JACKASSBUT
# Extracting the LULC for site: PBO_H2O_KAMASLLOYD
# Extracting the LULC for site: PBO_H2O_KEMMERERLF
# Extracting the LULC for site: PBO_H2O_KNOLLSWEST
# Extracting the LULC for site: PBO_H2O_LAKHENSHAW
# Extracting the LULC for site: PBO_H2O_LAMARARPT
# Extracting the LULC for site: PBO_H2O_LASTCHANCE
# Extracting the LULC for site: PBO_H2O_LITTLEBALD
# Extracting the LULC for site: PBO_H2O_LITTLELOST
# Extracting the LULC for site: PBO_H2O_MARSHALL2
# Extracting the LULC for site: PBO_H2O_MASW_SCGN
# Extracting the LULC for site: PBO_H2O_MATADORRCH
# Extracting the LULC for site: PBO_H2O_MCDERMITT
# Extracting the LULC for site: PBO_H2O_MCDNLDWELL
# Extracting the LULC for site: PBO_H2O_MEDICINELG
# Extracting the LULC for site: PBO_H2O_MIDDLEGATE
# Extracting the LULC for site: PBO_H2O_MONTICELLO
# Extracting the LULC for site: PBO_H2O_MOONEYCYN
# Extracting the LULC for site: PBO_H2O_MORROCREEK
# Extracting the LULC for site: PBO_H2O_MORROWAIR
# Extracting the LULC for site: PBO_H2O_MT_GLEASON
# Extracting the LULC for site: PBO_H2O_NDAP_SCGN
# Extracting the LULC for site: PBO_H2O_NIPOMO
# Extracting the LULC for site: PBO_H2O_Okla2
# Extracting the LULC for site: PBO_H2O_OWENSGORGE
# Extracting the LULC for site: PBO_H2O_PARKINSONF
# Extracting the LULC for site: PBO_H2O_POINT_LOMA
# Extracting the LULC for site: PBO_H2O_PORTALESAP
# Extracting the LULC for site: PBO_H2O_QCY2_BARD
# Extracting the LULC for site: PBO_H2O_QUILLAYUT
# Extracting the LULC for site: PBO_H2O_RANDOLPHLL
# Extracting the LULC for site: PBO_H2O_RAWLINSWWT
# Extracting the LULC for site: PBO_H2O_REDKNOLLS
# Extracting the LULC for site: PBO_H2O_REIDHILLVW
# Extracting the LULC for site: PBO_H2O_RIFLE_GCL
# Extracting the LULC for site: PBO_H2O_ROSASCYN
# Extracting the LULC for site: PBO_H2O_SAGEVALLEY
# Extracting the LULC for site: PBO_H2O_SALMONFALL
# Extracting the LULC for site: PBO_H2O_SANPETEVAL
# Extracting the LULC for site: PBO_H2O_SanSalvador
# Extracting the LULC for site: PBO_H2O_SCIA_SCGN
# Extracting the LULC for site: PBO_H2O_SDHL_SCGN
# Extracting the LULC for site: PBO_H2O_SEVILLETA_#1
# Extracting the LULC for site: PBO_H2O_SEVILLETA_#2
# Extracting the LULC for site: PBO_H2O_SHANIKO
# Extracting the LULC for site: PBO_H2O_SHOSHONERV
# Extracting the LULC for site: PBO_H2O_SIERRAARMY
# Extracting the LULC for site: PBO_H2O_SILVERLAKE
# Extracting the LULC for site: PBO_H2O_SISTERSHSL
# Extracting the LULC for site: PBO_H2O_SLAVENCYN
# Extracting the LULC for site: PBO_H2O_SMAPSITEA2
# Extracting the LULC for site: PBO_H2O_SPARLINRCH
# Extracting the LULC for site: PBO_H2O_SPIDERROCK
# Extracting the LULC for site: PBO_H2O_SPRECKLESS
# Extracting the LULC for site: PBO_H2O_SPRINGCREK
# Extracting the LULC for site: PBO_H2O_TENSLEEPTR
# Extracting the LULC for site: PBO_H2O_TEPUSQUET
# Extracting the LULC for site: PBO_H2O_TRESPIEDRA
# Extracting the LULC for site: PBO_H2O_TUBA_CITY
# Extracting the LULC for site: PBO_H2O_VAUGHNPTRL
# Extracting the LULC for site: PBO_H2O_VERNONHILL
# Extracting the LULC for site: PBO_H2O_VIDALJUNCT
# Extracting the LULC for site: PBO_H2O_VIGUSBUTTE
# Extracting the LULC for site: PBO_H2O_VIMT_SCGN
# Extracting the LULC for site: PBO_H2O_VINAHELITK
# Extracting the LULC for site: PBO_H2O_WAGONMOUND
# Extracting the LULC for site: PBO_H2O_WANSHIP2
# Extracting the LULC for site: PBO_H2O_WHEATLAND
# Extracting the LULC for site: PBO_H2O_WHITEWATER
# Extracting the LULC for site: PBO_H2O_WICKSRANCH
# Extracting the LULC for site: PBO_H2O_WILBURLEVA
# Extracting the LULC for site: PBO_H2O_WOODLANDFM
# Extracting the LULC for site: PBO_H2O_WRIGHTSPT
# Extracting the LULC for site: RISMA_CEF
# Extracting the LULC for site: RISMA_MB1
# Extracting the LULC for site: RISMA_MB10
# Extracting the LULC for site: RISMA_MB11
# Extracting the LULC for site: RISMA_MB12
# Extracting the LULC for site: RISMA_MB13
# Extracting the LULC for site: RISMA_MB2
# Extracting the LULC for site: RISMA_MB3
# Extracting the LULC for site: RISMA_MB4
# Extracting the LULC for site: RISMA_MB5
# Extracting the LULC for site: RISMA_MB6
# Extracting the LULC for site: RISMA_MB7
# Extracting the LULC for site: RISMA_MB8
# Extracting the LULC for site: RISMA_MB9
# Extracting the LULC for site: RISMA_ON2
# Extracting the LULC for site: RISMA_ON3
# Extracting the LULC for site: RISMA_ON4
# Extracting the LULC for site: RISMA_ON5
# Extracting the LULC for site: RISMA_ON6
# Extracting the LULC for site: RISMA_SK1
# Extracting the LULC for site: RISMA_SK2
# Extracting the LULC for site: RISMA_SK3
# Extracting the LULC for site: RISMA_SK4
# Extracting the LULC for site: SCAN_AAMU-jtg
# Extracting the LULC for site: SCAN_Abrams
# Extracting the LULC for site: SCAN_Adams_Ranch_#1
# Extracting the LULC for site: SCAN_Alcalde
# Extracting the LULC for site: SCAN_Alkali_Mesa
# Extracting the LULC for site: SCAN_Allen_Farms
# Extracting the LULC for site: SCAN_Ames
# Extracting the LULC for site: SCAN_Ash_Valley
# Extracting the LULC for site: SCAN_Beasley_Lake
# Extracting the LULC for site: SCAN_Beaumont
# Extracting the LULC for site: SCAN_Blue_Creek
# Extracting the LULC for site: SCAN_Bodie_Hills
# Extracting the LULC for site: SCAN_Bosque_Seco
# Extracting the LULC for site: SCAN_Bragg_Farm
# Extracting the LULC for site: SCAN_Broad_Acres
# Extracting the LULC for site: SCAN_Buckhorn
# Extracting the LULC for site: SCAN_Buffalo_Jump
# Extracting the LULC for site: SCAN_Busby_Farm
# Extracting the LULC for site: SCAN_Bushland_#1
# Extracting the LULC for site: SCAN_Cache_Junction
# Extracting the LULC for site: SCAN_Carver_Farm
# Extracting the LULC for site: SCAN_Cave_Valley
# Extracting the LULC for site: SCAN_Centralia_Lake
# Extracting the LULC for site: SCAN_Charkiln
# Extracting the LULC for site: SCAN_Chicken_Ridge
# Extracting the LULC for site: SCAN_Circleville
# Extracting the LULC for site: SCAN_CMRB_LTAR-MO
# Extracting the LULC for site: SCAN_Cochora_Ranch
# Extracting the LULC for site: SCAN_Combate
# Extracting the LULC for site: SCAN_Conrad_Ag_Rc
# Extracting the LULC for site: SCAN_Cook_Farm_Field_D
# Extracting the LULC for site: SCAN_Corozal
# Extracting the LULC for site: SCAN_Cper
# Extracting the LULC for site: SCAN_Crescent_Lake_#1
# Extracting the LULC for site: SCAN_Cullman-NAHRC
# Extracting the LULC for site: SCAN_Death_Valley_JCT
# Extracting the LULC for site: SCAN_Deep_Springs
# Extracting the LULC for site: SCAN_Dee_River_Ranch
# Extracting the LULC for site: SCAN_Desert_Center
# Extracting the LULC for site: SCAN_Dexter
# Extracting the LULC for site: SCAN_Doe_Ridge
# Extracting the LULC for site: SCAN_Eagle_Lake
# Extracting the LULC for site: SCAN_Eastland
# Extracting the LULC for site: SCAN_Eastview_Farm
# Extracting the LULC for site: SCAN_Elsberry_PMC
# Extracting the LULC for site: SCAN_Enterprise
# Extracting the LULC for site: SCAN_Ephraim
# Extracting the LULC for site: SCAN_Eros_Data_Center
# Extracting the LULC for site: SCAN_Essex
# Extracting the LULC for site: SCAN_Everglades_Ars
# Extracting the LULC for site: SCAN_Ford_Dry_Lake
# Extracting the LULC for site: SCAN_Fort_Assiniboine_#1
# Extracting the LULC for site: SCAN_Fort_Reno_#1
# Extracting the LULC for site: SCAN_Fortuna
# Extracting the LULC for site: SCAN_French_Gulch
# Extracting the LULC for site: SCAN_Geneva_#1
# Extracting the LULC for site: SCAN_Glacial_Ridge
# Extracting the LULC for site: SCAN_Goodwin_Creek_Pasture
# Extracting the LULC for site: SCAN_Goodwin_Creek_Timber
# Extracting the LULC for site: SCAN_Goshute
# Extracting the LULC for site: SCAN_Grantsville
# Extracting the LULC for site: SCAN_Green_River
# Extracting the LULC for site: SCAN_Grouse_Creek
# Extracting the LULC for site: SCAN_Guilarte_Forest
# Extracting the LULC for site: SCAN_Hals_Canyon
# Extracting the LULC for site: SCAN_Harms_Way
# Extracting the LULC for site: SCAN_Hodges
# Extracting the LULC for site: SCAN_Holden
# Extracting the LULC for site: SCAN_Hubbard_Brook
# Extracting the LULC for site: SCAN_Isabela
# Extracting the LULC for site: SCAN_Isbell_Farms
# Extracting the LULC for site: SCAN_Johnson_Farm
# Extracting the LULC for site: SCAN_Jordan
# Extracting the LULC for site: SCAN_Jordan_Valley_Cwma
# Extracting the LULC for site: SCAN_Jornada_Exp_Range
# Extracting the LULC for site: SCAN_Journagan_Ranch
# Extracting the LULC for site: SCAN_Kingsville
# Extracting the LULC for site: SCAN_Knox_City
# Extracting the LULC for site: SCAN_Koptis_Farms
# Extracting the LULC for site: SCAN_Ku-nesa
# Extracting the LULC for site: SCAN_Kyle_Canyon
# Extracting the LULC for site: SCAN_Levelland
# Extracting the LULC for site: SCAN_Lind_#1
# Extracting the LULC for site: SCAN_LINDSAY
# Extracting the LULC for site: SCAN_Little_Red_Fox
# Extracting the LULC for site: SCAN_Little_River
# Extracting the LULC for site: SCAN_Livingston-UWA
# Extracting the LULC for site: SCAN_Los_Lunas_Pmc
# Extracting the LULC for site: SCAN_Lovell_Summit
# Extracting the LULC for site: SCAN_Lovelock_Nnr
# Extracting the LULC for site: SCAN_Lye_Brook
# Extracting the LULC for site: SCAN_Lynhart_Ranch
# Extracting the LULC for site: SCAN_Mahantango_Ck
# Extracting the LULC for site: SCAN_Mammoth_Cave
# Extracting the LULC for site: SCAN_Mandan_#1
# Extracting the LULC for site: SCAN_Manderfield
# Extracting the LULC for site: SCAN_Marble_Creek
# Extracting the LULC for site: SCAN_Maricao_Forest
# Extracting the LULC for site: SCAN_Mark_Twain_HS
# Extracting the LULC for site: SCAN_Mason_#1
# Extracting the LULC for site: SCAN_Mayday
# Extracting the LULC for site: SCAN_Mcalister_Farm
# Extracting the LULC for site: SCAN_Mccracken_Mesa
# Extracting the LULC for site: SCAN_Milford
# Extracting the LULC for site: SCAN_Moccasin
# Extracting the LULC for site: SCAN_Molly_Caren_#1
# Extracting the LULC for site: SCAN_Monocline_Ridge
# Extracting the LULC for site: SCAN_Morgan
# Extracting the LULC for site: SCAN_Morris_Farms
# Extracting the LULC for site: SCAN_Mountain_Home
# Extracting the LULC for site: SCAN_Mount_Mansfield
# Extracting the LULC for site: SCAN_Mt_Vernon
# Extracting the LULC for site: SCAN_Nephi
# Extracting the LULC for site: SCAN_North_Issaquena
# Extracting the LULC for site: SCAN_N_Piedmont_Arec
# Extracting the LULC for site: SCAN_Nunn_#1
# Extracting the LULC for site: SCAN_Onward
# Extracting the LULC for site: SCAN_Orchard_Range_Site
# Extracting the LULC for site: SCAN_Panguitch
# Extracting the LULC for site: SCAN_Park_Valley
# Extracting the LULC for site: SCAN_Pee_Dee
# Extracting the LULC for site: SCAN_Perdido_Riv_Farms
# Extracting the LULC for site: SCAN_Perthshire
# Extracting the LULC for site: SCAN_Phillipsburg
# Extracting the LULC for site: SCAN_Pine_Nut
# Extracting the LULC for site: SCAN_Porter_Canyon
# Extracting the LULC for site: SCAN_Powder_Mill
# Extracting the LULC for site: SCAN_Powell_Gardens
# Extracting the LULC for site: SCAN_Prairie_View_#1
# Extracting the LULC for site: SCAN_Price
# Extracting the LULC for site: SCAN_Princeton_#1
# Extracting the LULC for site: SCAN_Reynolds_Homestead
# Extracting the LULC for site: SCAN_Riesel
# Extracting the LULC for site: SCAN_River_Road_Farms
# Extracting the LULC for site: SCAN_Rock_Springs_Pa
# Extracting the LULC for site: SCAN_Rogers_Farm_#1
# Extracting the LULC for site: SCAN_San_Angelo
# Extracting the LULC for site: SCAN_Sand_Hollow
# Extracting the LULC for site: SCAN_Sandy_Ridge
# Extracting the LULC for site: SCAN_Schell-Osage
# Extracting the LULC for site: SCAN_Scott
# Extracting the LULC for site: SCAN_Sellers_Lake_#1
# Extracting the LULC for site: SCAN_Selma
# Extracting the LULC for site: SCAN_Sevilleta
# Extracting the LULC for site: SCAN_Shadow_Mtns
# Extracting the LULC for site: SCAN_Shagbark_Hills
# Extracting the LULC for site: SCAN_Shaw_Nature_Reserve
# Extracting the LULC for site: SCAN_SHELDON
# Extracting the LULC for site: SCAN_Shenandoah
# Extracting the LULC for site: SCAN_Sidney
# Extracting the LULC for site: SCAN_Silver_City
# Extracting the LULC for site: SCAN_Spickard
# Extracting the LULC for site: SCAN_Split_Mountain
# Extracting the LULC for site: SCAN_Spooky
# Extracting the LULC for site: SCAN_Stanley_Farm
# Extracting the LULC for site: SCAN_Starkville
# Extracting the LULC for site: SCAN_Stephenville
# Extracting the LULC for site: SCAN_Stubblefield
# Extracting the LULC for site: SCAN_Sudduth_Farms
# Extracting the LULC for site: SCAN_Sunleaf_Nursery
# Extracting the LULC for site: SCAN_TABLE_MOUNTAIN
# Extracting the LULC for site: SCAN_Tidewater_#1
# Extracting the LULC for site: SCAN_Tidewater_Arec
# Extracting the LULC for site: SCAN_TNC_Fort_Bayou
# Extracting the LULC for site: SCAN_Torrington_#1
# Extracting the LULC for site: SCAN_Trough_Springs
# Extracting the LULC for site: SCAN_Tule_Valley
# Extracting the LULC for site: SCAN_Tunica
# Extracting the LULC for site: SCAN_Tuskegee
# Extracting the LULC for site: SCAN_Twin_Pines_Conservation_Area
# Extracting the LULC for site: SCAN_UAPB_Campus-PB
# Extracting the LULC for site: SCAN_UAPB_Dewitt
# Extracting the LULC for site: SCAN_UAPB_Earle
# Extracting the LULC for site: SCAN_UAPB_Lonoke_Farm
# Extracting the LULC for site: SCAN_UAPB_Marianna
# Extracting the LULC for site: SCAN_UAPB_Point_Remove
# Extracting the LULC for site: SCAN_Uvalde
# Extracting the LULC for site: SCAN_Uw_Platteville
# Extracting the LULC for site: SCAN_Vance
# Extracting the LULC for site: SCAN_Vermillion
# Extracting the LULC for site: SCAN_Vernon
# Extracting the LULC for site: SCAN_Violett
# Extracting the LULC for site: SCAN_Wabeno_#1
# Extracting the LULC for site: SCAN_Wakulla_#1
# Extracting the LULC for site: SCAN_Walnut_Gulch_#1
# Extracting the LULC for site: SCAN_Watkinsville_#1
# Extracting the LULC for site: SCAN_Wedowee
# Extracting the LULC for site: SCAN_Weslaco
# Extracting the LULC for site: SCAN_West_Summit
# Extracting the LULC for site: SCAN_WTARS
# Extracting the LULC for site: SCAN_Youmans_Farm
# Extracting the LULC for site: SNOTEL_AGUA_CANYON
# Extracting the LULC for site: SNOTEL_ANNIE_SPRINGS
# Extracting the LULC for site: SNOTEL_ARAPAHO_RIDGE
# Extracting the LULC for site: SNOTEL_ATLANTA_SUMMIT
# Extracting the LULC for site: SNOTEL_Baker_Butte
# Extracting the LULC for site: SNOTEL_BAKER_BUTTE_SMT
# Extracting the LULC for site: SNOTEL_BALDY
# Extracting the LULC for site: SNOTEL_BANNER_SUMMIT
# Extracting the LULC for site: SNOTEL_Bar_M
# Extracting the LULC for site: SNOTEL_BEAR_CREEK
# Extracting the LULC for site: SNOTEL_BEAR_RIVER_RS
# Extracting the LULC for site: SNOTEL_BEAVER_DAMS
# Extracting the LULC for site: SNOTEL_BEAVER_DIVIDE
# Extracting the LULC for site: SNOTEL_BEAVER_PASS
# Extracting the LULC for site: SNOTEL_BEN_LOMOND_PEAK
# Extracting the LULC for site: SNOTEL_BEN_LOMOND_TRAIL
# Extracting the LULC for site: SNOTEL_BERRY_CREEK
# Extracting the LULC for site: SNOTEL_BERTHOUD_SUMMIT
# Extracting the LULC for site: SNOTEL_Bevans_Cabin
# Extracting the LULC for site: SNOTEL_BIG_BEND
# Extracting the LULC for site: SNOTEL_BIG_CREEK_SUM
# Extracting the LULC for site: SNOTEL_BIG_FLAT
# Extracting the LULC for site: SNOTEL_BIG_MEADOW
# Extracting the LULC for site: SNOTEL_BIG_SANDY_OPENING
# Extracting the LULC for site: SNOTEL_BILLIE_CREEK_DIVIDE
# Extracting the LULC for site: SNOTEL_BIRD_CREEK
# Extracting the LULC for site: SNOTEL_BLACK_FLAT-U.M._CK
# Extracting the LULC for site: SNOTEL_BLACKHALL_MTN
# Extracting the LULC for site: SNOTEL_Black_Mesa
# Extracting the LULC for site: SNOTEL_BLACKS_FORK_JCT
# Extracting the LULC for site: SNOTEL_BLUE_LAKES
# Extracting the LULC for site: SNOTEL_BOGUS_BASIN
# Extracting the LULC for site: SNOTEL_BOURNE
# Extracting the LULC for site: SNOTEL_BOX_CREEK
# Extracting the LULC for site: SNOTEL_BRIAN_HEAD
# Extracting the LULC for site: SNOTEL_BRIGHTON
# Extracting the LULC for site: SNOTEL_BRISTLECONE_TRAIL
# Extracting the LULC for site: SNOTEL_BROWN_DUCK
# Extracting the LULC for site: SNOTEL_BROWN_TOP
# Extracting the LULC for site: SNOTEL_BRUMLEY
# Extracting the LULC for site: SNOTEL_BUCKBOARD_FLAT
# Extracting the LULC for site: SNOTEL_BUCK_FLAT
# Extracting the LULC for site: SNOTEL_BUCKINGHORSE
# Extracting the LULC for site: SNOTEL_BUCK_PASTURE
# Extracting the LULC for site: SNOTEL_BUCKSKIN_JOE
# Extracting the LULC for site: SNOTEL_BUCKSKIN_LOWER
# Extracting the LULC for site: SNOTEL_BUG_LAKE
# Extracting the LULC for site: SNOTEL_BURNSIDE_LAKE
# Extracting the LULC for site: SNOTEL_BURNT_MOUNTAIN
# Extracting the LULC for site: SNOTEL_BURRO_MOUNTAIN
# Extracting the LULC for site: SNOTEL_BURTS_MILLER_RANCH
# Extracting the LULC for site: SNOTEL_BUTTE
# Extracting the LULC for site: SNOTEL_CAMP_JACKSON
# Extracting the LULC for site: SNOTEL_CARSON_PASS
# Extracting the LULC for site: SNOTEL_CASCADE_#2
# Extracting the LULC for site: SNOTEL_CASCADE_MOUNTAIN
# Extracting the LULC for site: SNOTEL_CASTLE_VALLEY
# Extracting the LULC for site: SNOTEL_CAVE_MOUNTAIN
# Extracting the LULC for site: SNOTEL_CAYUSE_PASS
# Extracting the LULC for site: SNOTEL_Chalender
# Extracting the LULC for site: SNOTEL_CHALK_CREEK_#1
# Extracting the LULC for site: SNOTEL_CHALK_CREEK_#2
# Extracting the LULC for site: SNOTEL_CHEMULT_ALTERNATE
# Extracting the LULC for site: SNOTEL_CHEPETA
# Extracting the LULC for site: SNOTEL_CHOCOLATE_GULCH
# Extracting the LULC for site: SNOTEL_CINNABAR_PARK
# Extracting the LULC for site: SNOTEL_CLACKAMAS_LAKE
# Extracting the LULC for site: SNOTEL_CLAYTON_SPRINGS
# Extracting the LULC for site: SNOTEL_CLEAR_CREEK_#1
# Extracting the LULC for site: SNOTEL_CLEAR_CREEK_#2
# Extracting the LULC for site: SNOTEL_CLEAR_LAKE
# Extracting the LULC for site: SNOTEL_COCHETOPA_PASS
# Extracting the LULC for site: SNOTEL_Columbia_Basin
# Extracting the LULC for site: SNOTEL_Copper_Mountain
# Extracting the LULC for site: SNOTEL_Corduroy_Flat
# Extracting the LULC for site: SNOTEL_Corral
# Extracting the LULC for site: SNOTEL_CORRAL_CANYON
# Extracting the LULC for site: SNOTEL_CRAB_CREEK
# Extracting the LULC for site: SNOTEL_CRATER_MEADOWS
# Extracting the LULC for site: SNOTEL_CROW_CREEK
# Extracting the LULC for site: SNOTEL_CSS_LAB
# Extracting the LULC for site: SNOTEL_CULEBRA_#2
# Extracting the LULC for site: SNOTEL_CURRANT_CREEK
# Extracting the LULC for site: SNOTEL_DANIELS-STRAWBERRY
# Extracting the LULC for site: SNOTEL_Defiance_Mines
# Extracting the LULC for site: SNOTEL_DIAMOND_PEAK
# Extracting the LULC for site: SNOTEL_DILLS_CAMP
# Extracting the LULC for site: SNOTEL_DISASTER_PEAK
# Extracting the LULC for site: SNOTEL_Dollarhide_Summit
# Extracting the LULC for site: SNOTEL_DONKEY_RESERVOIR
# Extracting the LULC for site: SNOTEL_DORSEY_BASIN
# Extracting the LULC for site: SNOTEL_DRAW_CREEK
# Extracting the LULC for site: SNOTEL_DRY_BREAD_POND
# Extracting the LULC for site: SNOTEL_Dry_Creek
# Extracting the LULC for site: SNOTEL_DRY_FORK
# Extracting the LULC for site: SNOTEL_DRY_LAKE
# Extracting the LULC for site: SNOTEL_EAST_RIM_DIVIDE
# Extracting the LULC for site: SNOTEL_EAST_WILLOW_CREEK
# Extracting the LULC for site: SNOTEL_EBBETTS_PASS
# Extracting the LULC for site: SNOTEL_ECHO_PEAK
# Extracting the LULC for site: SNOTEL_EF_BLACKS_FORK_GS
# Extracting the LULC for site: SNOTEL_Elk_Cabin
# Extracting the LULC for site: SNOTEL_FALLEN_LEAF
# Extracting the LULC for site: SNOTEL_FARMINGTON
# Extracting the LULC for site: SNOTEL_FARMINGTON_LOWER
# Extracting the LULC for site: SNOTEL_FARNSWORTH_LAKE
# Extracting the LULC for site: SNOTEL_FAWN_CREEK
# Extracting the LULC for site: SNOTEL_FISH_LAKE_UTAH
# Extracting the LULC for site: SNOTEL_FIVE_POINTS_LAKE
# Extracting the LULC for site: SNOTEL_FORESTDALE_CREEK
# Extracting the LULC for site: SNOTEL_FORT_VALLEY
# Extracting the LULC for site: SNOTEL_FRANKLIN_BASIN
# Extracting the LULC for site: SNOTEL_FREMONT_PASS
# Extracting the LULC for site: SNOTEL_Fry_Canyon
# Extracting the LULC for site: SNOTEL_GALENA_SUMMIT
# Extracting the LULC for site: SNOTEL_Gallegos_Peak
# Extracting the LULC for site: SNOTEL_GARDEN_CITY_SUMMIT
# Extracting the LULC for site: SNOTEL_GARDNER_PEAK
# Extracting the LULC for site: SNOTEL_GBRC_HQ
# Extracting the LULC for site: SNOTEL_GBRC_MEADOWS
# Extracting the LULC for site: SNOTEL_GEORGE_CREEK
# Extracting the LULC for site: SNOTEL_GIVEOUT
# Extracting the LULC for site: SNOTEL_GOLCONDA
# Extracting the LULC for site: SNOTEL_GOLD_AXE_CAMP
# Extracting the LULC for site: SNOTEL_GOOSEBERRY_R.S.
# Extracting the LULC for site: SNOTEL_GOOSEBERRY_R.S._UP
# Extracting the LULC for site: SNOTEL_GRAND_TARGHEE
# Extracting the LULC for site: SNOTEL_Granite_Creek
# Extracting the LULC for site: SNOTEL_GRANITE_PEAK
# Extracting the LULC for site: SNOTEL_GREEN_MOUNTAIN
# Extracting the LULC for site: SNOTEL_GRIZZLY_PEAK
# Extracting the LULC for site: SNOTEL_Gunsight_Pass
# Extracting the LULC for site: SNOTEL_GUTZ_PEAK
# Extracting the LULC for site: SNOTEL_HAGANS_MEADOW
# Extracting the LULC for site: SNOTEL_HAPPY_JACK
# Extracting the LULC for site: SNOTEL_HARDSCRABBLE
# Extracting the LULC for site: SNOTEL_HARRIS_FLAT
# Extracting the LULC for site: SNOTEL_HARTS_PASS
# Extracting the LULC for site: SNOTEL_Hawley_Lake
# Extracting the LULC for site: SNOTEL_HAYDEN_FORK
# Extracting the LULC for site: SNOTEL_HEAVENLY_VALLEY
# Extracting the LULC for site: SNOTEL_HEWINTA
# Extracting the LULC for site: SNOTEL_HICKERSON_PARK
# Extracting the LULC for site: SNOTEL_HIGH_RIDGE
# Extracting the LULC for site: SNOTEL_HILTS_CREEK
# Extracting the LULC for site: SNOTEL_Hobble_Creek
# Extracting the LULC for site: SNOTEL_HOLE-IN-MOUNTAIN
# Extracting the LULC for site: SNOTEL_HOLE-IN-ROCK
# Extracting the LULC for site: SNOTEL_HOLLAND_MEADOWS
# Extracting the LULC for site: SNOTEL_HOOSIER_PASS
# Extracting the LULC for site: SNOTEL_Hopewell
# Extracting the LULC for site: SNOTEL_HORSE_MEADOW
# Extracting the LULC for site: SNOTEL_HORSE_RIDGE
# Extracting the LULC for site: SNOTEL_Huntington_Horse
# Extracting the LULC for site: SNOTEL_HYNDMAN
# Extracting the LULC for site: SNOTEL_INDEPENDENCE_CAMP
# Extracting the LULC for site: SNOTEL_INDEPENDENCE_CREEK
# Extracting the LULC for site: SNOTEL_INDEPENDENCE_LAKE
# Extracting the LULC for site: SNOTEL_INDIAN_CANYON
# Extracting the LULC for site: SNOTEL_INDIAN_ROCK
# Extracting the LULC for site: SNOTEL_JACK_CREEK_UPPER
# Extracting the LULC for site: SNOTEL_JACKSON_PEAK
# Extracting the LULC for site: SNOTEL_JACKS_PEAK
# Extracting the LULC for site: SNOTEL_JACKWHACKER_GULCH
# Extracting the LULC for site: SNOTEL_Jakes_Creek
# Extracting the LULC for site: SNOTEL_JONES_CORRAL
# Extracting the LULC for site: SNOTEL_KALAMAZOO
# Extracting the LULC for site: SNOTEL_KELLEY_R.S.
# Extracting the LULC for site: SNOTEL_KILFOIL_CREEK
# Extracting the LULC for site: SNOTEL_KIMBERLY_MINE
# Extracting the LULC for site: SNOTEL_KINGS_CABIN
# Extracting the LULC for site: SNOTEL_KLONDIKE_NARROWS
# Extracting the LULC for site: SNOTEL_KOLOB
# Extracting the LULC for site: SNOTEL_LAKEFORK_#1
# Extracting the LULC for site: SNOTEL_LAKEFORK_#3
# Extracting the LULC for site: SNOTEL_Lakefork_Basin
# Extracting the LULC for site: SNOTEL_LAMANCE_CREEK
# Extracting the LULC for site: SNOTEL_LAMOILLE_#3
# Extracting the LULC for site: SNOTEL_LAPRELE_CREEK
# Extracting the LULC for site: SNOTEL_LARSEN_CREEK
# Extracting the LULC for site: SNOTEL_LASAL_MOUNTAIN
# Extracting the LULC for site: SNOTEL_LASAL_MOUNTAIN-LOWER
# Extracting the LULC for site: SNOTEL_LAUREL_DRAW
# Extracting the LULC for site: SNOTEL_LEAVITT_LAKE
# Extracting the LULC for site: SNOTEL_LEAVITT_MEADOWS
# Extracting the LULC for site: SNOTEL_LEE_CANYON
# Extracting the LULC for site: SNOTEL_LEWIS_LAKE_DIVIDE
# Extracting the LULC for site: SNOTEL_LEWIS_PEAK
# Extracting the LULC for site: SNOTEL_LIGHTNING_RIDGE
# Extracting the LULC for site: SNOTEL_LILY_LAKE
# Extracting the LULC for site: SNOTEL_LILY_POND
# Extracting the LULC for site: SNOTEL_LITTLE_BEAR
# Extracting the LULC for site: SNOTEL_LITTLE_GRASSY
# Extracting the LULC for site: SNOTEL_LITTLE_SNAKE_RIVER
# Extracting the LULC for site: SNOTEL_Little_Valley
# Extracting the LULC for site: SNOTEL_LIZARD_HEAD_PASS
# Extracting the LULC for site: SNOTEL_LOBDELL_LAKE
# Extracting the LULC for site: SNOTEL_LONE_CONE
# Extracting the LULC for site: SNOTEL_Lonesome_Beaver
# Extracting the LULC for site: SNOTEL_LONG_DRAW_RESV
# Extracting the LULC for site: SNOTEL_LONG_FLAT
# Extracting the LULC for site: SNOTEL_LONG_VALLEY
# Extracting the LULC for site: SNOTEL_LONG_VALLEY_JCT
# Extracting the LULC for site: SNOTEL_LOOKOUT
# Extracting the LULC for site: SNOTEL_LOOKOUT_PEAK
# Extracting the LULC for site: SNOTEL_LOST_CREEK_RESV
# Extracting the LULC for site: SNOTEL_LOST_DOG
# Extracting the LULC for site: SNOTEL_LOST_HORSE
# Extracting the LULC for site: SNOTEL_LOUIS_MEADOW
# Extracting the LULC for site: SNOTEL_MADISON_BUTTE
# Extracting the LULC for site: SNOTEL_MAGIC_MOUNTAIN
# Extracting the LULC for site: SNOTEL_MAMMOTH-COTTONWOOD
# Extracting the LULC for site: SNOTEL_MARLETTE_LAKE
# Extracting the LULC for site: SNOTEL_Marten_Ridge
# Extracting the LULC for site: SNOTEL_MEDANO_PASS
# Extracting the LULC for site: SNOTEL_Med_Bow
# Extracting the LULC for site: SNOTEL_MERCHANT_VALLEY
# Extracting the LULC for site: SNOTEL_Merritt_Mountain
# Extracting the LULC for site: SNOTEL_MF_Nooksack
# Extracting the LULC for site: SNOTEL_MICA_CREEK
# Extracting the LULC for site: SNOTEL_MICHIGAN_CREEK
# Extracting the LULC for site: SNOTEL_Midas
# Extracting the LULC for site: SNOTEL_MIDDLE_FORK_CAMP
# Extracting the LULC for site: SNOTEL_MIDWAY_VALLEY
# Extracting the LULC for site: SNOTEL_MILL-D_NORTH
# Extracting the LULC for site: SNOTEL_MILLER_WOODS
# Extracting the LULC for site: SNOTEL_MINING_FORK
# Extracting the LULC for site: SNOTEL_MONITOR_PASS
# Extracting the LULC for site: SNOTEL_MONTE_CRISTO
# Extracting the LULC for site: SNOTEL_Mormon_Mountain
# Extracting the LULC for site: SNOTEL_MORMON_MTN_SUMMIT
# Extracting the LULC for site: SNOTEL_MOSBY_MTN.
# Extracting the LULC for site: SNOTEL_MOSCOW_MOUNTAIN
# Extracting the LULC for site: SNOTEL_MOSES_MTN
# Extracting the LULC for site: SNOTEL_MOSQUITO_RIDGE
# Extracting the LULC for site: SNOTEL_MOSS_SPRINGS
# Extracting the LULC for site: SNOTEL_MT._HOWARD
# Extracting the LULC for site: SNOTEL_MT_Baldy
# Extracting the LULC for site: SNOTEL_Mt_Pennell
# Extracting the LULC for site: SNOTEL_MT_ROSE_SKI_AREA
# Extracting the LULC for site: SNOTEL_MUD_FLAT
# Extracting the LULC for site: SNOTEL_MYRTLE_CREEK
# Extracting the LULC for site: SNOTEL_NAVAJO_WHISKEY_CK
# Extracting the LULC for site: SNOTEL_OAK_CREEK
# Extracting the LULC for site: SNOTEL_PALO
# Extracting the LULC for site: SNOTEL_Panguitch_Lake_RS
# Extracting the LULC for site: SNOTEL_PARADISE
# Extracting the LULC for site: SNOTEL_PARK_CONE
# Extracting the LULC for site: SNOTEL_PARK_CREEK_RIDGE
# Extracting the LULC for site: SNOTEL_PARK_RESERVOIR
# Extracting the LULC for site: SNOTEL_PARLEYS_SUMMIT
# Extracting the LULC for site: SNOTEL_PARRISH_CREEK
# Extracting the LULC for site: SNOTEL_PAYSON_R.S.
# Extracting the LULC for site: SNOTEL_PHANTOM_VALLEY
# Extracting the LULC for site: SNOTEL_PICKLE_KEG
# Extracting the LULC for site: SNOTEL_PIERCE_R.S.
# Extracting the LULC for site: SNOTEL_PINE_CREEK
# Extracting the LULC for site: SNOTEL_POCKET_CREEK
# Extracting the LULC for site: SNOTEL_POISON_FLAT
# Extracting the LULC for site: SNOTEL_Pole_Canyon
# Extracting the LULC for site: SNOTEL_POLE_CREEK_R.S.
# Extracting the LULC for site: SNOTEL_PORPHYRY_CREEK
# Extracting the LULC for site: SNOTEL_QUARTZ_MOUNTAIN
# Extracting the LULC for site: SNOTEL_QUARTZ_PEAK
# Extracting the LULC for site: SNOTEL_Quemazon
# Extracting the LULC for site: SNOTEL_RAGGED_MOUNTAIN
# Extracting the LULC for site: SNOTEL_RAINBOW_CANYON
# Extracting the LULC for site: SNOTEL_RAINY_PASS
# Extracting the LULC for site: SNOTEL_Redden_Mine_Lwr
# Extracting the LULC for site: SNOTEL_RED_PINE_RIDGE
# Extracting the LULC for site: SNOTEL_RED_RIVER_PASS_#2
# Extracting the LULC for site: SNOTEL_Rees_Flat
# Extracting the LULC for site: SNOTEL_REYNOLDS_CREEK
# Extracting the LULC for site: SNOTEL_Rio_Santa_Barbara
# Extracting the LULC for site: SNOTEL_ROCK_CREEK
# Extracting the LULC for site: SNOTEL_ROCK_SPRINGS
# Extracting the LULC for site: SNOTEL_ROCKY_BASIN-SETTLEME
# Extracting the LULC for site: SNOTEL_ROUGH_AND_TUMBLE
# Extracting the LULC for site: SNOTEL_RUBICON_#2
# Extracting the LULC for site: SNOTEL_SAGE_CREEK_BASIN
# Extracting the LULC for site: SNOTEL_SALMON_MEADOWS
# Extracting the LULC for site: SNOTEL_SALT_CREEK_FALLS
# Extracting the LULC for site: SNOTEL_SALT_RIVER_SUMMIT
# Extracting the LULC for site: SNOTEL_Santa_Fe
# Extracting the LULC for site: SNOTEL_SASSE_RIDGE
# Extracting the LULC for site: SNOTEL_SAVAGE_PASS
# Extracting the LULC for site: SNOTEL_Sawtooth
# Extracting the LULC for site: SNOTEL_SCHNEIDER_MEADOWS
# Extracting the LULC for site: SNOTEL_SCHOFIELD_PASS
# Extracting the LULC for site: SNOTEL_SEELEY_CREEK
# Extracting the LULC for site: SNOTEL_Senorita_Divide_#2
# Extracting the LULC for site: SNOTEL_SEVENTYSIX_CREEK
# Extracting the LULC for site: SNOTEL_SHANGHI_SUMMIT
# Extracting the LULC for site: SNOTEL_SHARKSTOOTH
# Extracting the LULC for site: SNOTEL_SHEEP_MTN.
# Extracting the LULC for site: SNOTEL_Sherwin
# Extracting the LULC for site: SNOTEL_SHUREE
# Extracting the LULC for site: SNOTEL_SIERRA_BLANCA
# Extracting the LULC for site: SNOTEL_SILVER_CREEK
# Extracting the LULC for site: SNOTEL_Silver_Creek_Nv
# Extracting the LULC for site: SNOTEL_SILVIES
# Extracting the LULC for site: SNOTEL_SLUMGULLION
# Extracting the LULC for site: SNOTEL_SMILEY_MOUNTAIN
# Extracting the LULC for site: SNOTEL_SMITH_and_MOREHOUSE
# Extracting the LULC for site: SNOTEL_SNAKE_RIVER_STATION
# Extracting the LULC for site: SNOTEL_SNOWBIRD
# Extracting the LULC for site: SNOTEL_SNOW_MOUNTAIN
# Extracting the LULC for site: SNOTEL_Snowstorm_Mtn
# Extracting the LULC for site: SNOTEL_SOMSEN_RANCH
# Extracting the LULC for site: SNOTEL_SONORA_PASS
# Extracting the LULC for site: SNOTEL_SOURDOUGH_GULCH
# Extracting the LULC for site: SNOTEL_SOUTH_MTN.
# Extracting the LULC for site: SNOTEL_SPIRIT_LK
# Extracting the LULC for site: SNOTEL_SPRATT_CREEK
# Extracting the LULC for site: SNOTEL_SQUAW_SPRINGS
# Extracting the LULC for site: SNOTEL_SQUAW_VALLEY_G.C.
# Extracting the LULC for site: SNOTEL_Stag_Mountain
# Extracting the LULC for site: SNOTEL_State_Line
# Extracting the LULC for site: SNOTEL_STEEL_CREEK_PARK
# Extracting the LULC for site: SNOTEL_STRAWBERRY_DIVIDE
# Extracting the LULC for site: SNOTEL_SUCKER_CREEK
# Extracting the LULC for site: SNOTEL_SUMMIT_LK
# Extracting the LULC for site: SNOTEL_SUMMIT_MEADOW
# Extracting the LULC for site: SNOTEL_SUMMIT_RANCH
# Extracting the LULC for site: SNOTEL_Sunflower_Flat
# Extracting the LULC for site: SNOTEL_Suu_Ranch
# Extracting the LULC for site: SNOTEL_SWEDE_PEAK
# Extracting the LULC for site: SNOTEL_TAHOE_CITY_CROSS
# Extracting the LULC for site: SNOTEL_Takka_Wiiya
# Extracting the LULC for site: SNOTEL_TAOS_POWDERHORN
# Extracting the LULC for site: SNOTEL_TAYLOR_BUTTE
# Extracting the LULC for site: SNOTEL_TAYLOR_CANYON
# Extracting the LULC for site: SNOTEL_TEMPLE_FORK
# Extracting the LULC for site: SNOTEL_Tent_Mtn_Lower
# Extracting the LULC for site: SNOTEL_THAYNES_CANYON
# Extracting the LULC for site: SNOTEL_Thistle_Flat
# Extracting the LULC for site: SNOTEL_Thumb_Divide
# Extracting the LULC for site: SNOTEL_TIMBERLINE
# Extracting the LULC for site: SNOTEL_TIMPANOGOS_DIVIDE
# Extracting the LULC for site: SNOTEL_TIPTON
# Extracting the LULC for site: SNOTEL_TOE_JAM
# Extracting the LULC for site: SNOTEL_TOGWOTEE_PASS
# Extracting the LULC for site: SNOTEL_TONY_GROVE_LAKE
# Extracting the LULC for site: SNOTEL_TONY_GROVE_RS
# Extracting the LULC for site: SNOTEL_TOUCHET
# Extracting the LULC for site: SNOTEL_Tres_Ritos
# Extracting the LULC for site: SNOTEL_TRIAL_LAKE
# Extracting the LULC for site: SNOTEL_TROUGH
# Extracting the LULC for site: SNOTEL_TROUT_CREEK
# Extracting the LULC for site: SNOTEL_TRUCKEE_#2
# Extracting the LULC for site: SNOTEL_Upper_Joes_Valley
# Extracting the LULC for site: SNOTEL_UPPER_RIO_GRANDE
# Extracting the LULC for site: SNOTEL_UPPER_SAN_JUAN
# Extracting the LULC for site: SNOTEL_UPPER_TAYLOR
# Extracting the LULC for site: SNOTEL_USU_DOC_DANIEL
# Extracting the LULC for site: SNOTEL_VACARRO_SPRING
# Extracting the LULC for site: SNOTEL_Vacas_Locas
# Extracting the LULC for site: SNOTEL_VAN_WYCK
# Extracting the LULC for site: SNOTEL_VERNON_CREEK
# Extracting the LULC for site: SNOTEL_VIRGINIA_LAKES_RIDGE
# Extracting the LULC for site: SNOTEL_WARD_CREEK_#3
# Extracting the LULC for site: SNOTEL_WARD_MOUNTAIN
# Extracting the LULC for site: SNOTEL_WATERHOLE
# Extracting the LULC for site: SNOTEL_WEBSTER_FLAT
# Extracting the LULC for site: SNOTEL_WESNER_SPRINGS
# Extracting the LULC for site: SNOTEL_WHEELER_PEAK
# Extracting the LULC for site: SNOTEL_WHISKEY_CK
# Extracting the LULC for site: SNOTEL_WHITE_HORSE_LAKE
# Extracting the LULC for site: SNOTEL_WHITE_RIVER_#1
# Extracting the LULC for site: SNOTEL_White_River_Nv
# Extracting the LULC for site: SNOTEL_WIDTSOE_#3
# Extracting the LULC for site: SNOTEL_WILD_BASIN
# Extracting the LULC for site: SNOTEL_WILDHORSE_DIVIDE
# Extracting the LULC for site: SNOTEL_WILSON_CREEK
# Extracting the LULC for site: SNOTEL_WINDY_PEAK
# Extracting the LULC for site: SNOTEL_WOLF_CREEK_SUMMIT
# Extracting the LULC for site: SNOTEL_Wrigley_Creek
# Extracting the LULC for site: SNOTEL_Yankee_Reservoir
# Extracting the LULC for site: SNOTEL_ZIRKEL
# Extracting the LULC for site: SOILSCAPE_node101
# Extracting the LULC for site: SOILSCAPE_node1017
# Extracting the LULC for site: SOILSCAPE_node1018
# Extracting the LULC for site: SOILSCAPE_node1019
# Extracting the LULC for site: SOILSCAPE_node102
# Extracting the LULC for site: SOILSCAPE_node1020
# Extracting the LULC for site: SOILSCAPE_node1021
# Extracting the LULC for site: SOILSCAPE_node1022
# Extracting the LULC for site: SOILSCAPE_node1023
# Extracting the LULC for site: SOILSCAPE_node1025
# Extracting the LULC for site: SOILSCAPE_node1027
# Extracting the LULC for site: SOILSCAPE_node1028
# Extracting the LULC for site: SOILSCAPE_node1029
# Extracting the LULC for site: SOILSCAPE_node103
# Extracting the LULC for site: SOILSCAPE_node1030
# Extracting the LULC for site: SOILSCAPE_node1031
# Extracting the LULC for site: SOILSCAPE_node105
# Extracting the LULC for site: SOILSCAPE_node106
# Extracting the LULC for site: SOILSCAPE_node107
# Extracting the LULC for site: SOILSCAPE_node108
# Extracting the LULC for site: SOILSCAPE_node111
# Extracting the LULC for site: SOILSCAPE_node112
# Extracting the LULC for site: SOILSCAPE_node114
# Extracting the LULC for site: SOILSCAPE_node115
# Extracting the LULC for site: SOILSCAPE_node116
# Extracting the LULC for site: SOILSCAPE_node119
# Extracting the LULC for site: SOILSCAPE_node120
# Extracting the LULC for site: SOILSCAPE_node1201
# Extracting the LULC for site: SOILSCAPE_node1202
# Extracting the LULC for site: SOILSCAPE_node1205
# Extracting the LULC for site: SOILSCAPE_node1206
# Extracting the LULC for site: SOILSCAPE_node121
# Extracting the LULC for site: SOILSCAPE_node1400
# Extracting the LULC for site: SOILSCAPE_node1401
# Extracting the LULC for site: SOILSCAPE_node1402
# Extracting the LULC for site: SOILSCAPE_node1403
# Extracting the LULC for site: SOILSCAPE_node1404
# Extracting the LULC for site: SOILSCAPE_node1405
# Extracting the LULC for site: SOILSCAPE_node1406
# Extracting the LULC for site: SOILSCAPE_node1407
# Extracting the LULC for site: SOILSCAPE_node1408
# Extracting the LULC for site: SOILSCAPE_node1409
# Extracting the LULC for site: SOILSCAPE_node1500
# Extracting the LULC for site: SOILSCAPE_node1501
# Extracting the LULC for site: SOILSCAPE_node1502
# Extracting the LULC for site: SOILSCAPE_node1503
# Extracting the LULC for site: SOILSCAPE_node1504
# Extracting the LULC for site: SOILSCAPE_node1505
# Extracting the LULC for site: SOILSCAPE_node1506
# Extracting the LULC for site: SOILSCAPE_node1507
# Extracting the LULC for site: SOILSCAPE_node401
# Extracting the LULC for site: SOILSCAPE_node403
# Extracting the LULC for site: SOILSCAPE_node404
# Extracting the LULC for site: SOILSCAPE_node405
# Extracting the LULC for site: SOILSCAPE_node406
# Extracting the LULC for site: SOILSCAPE_node408
# Extracting the LULC for site: SOILSCAPE_node410
# Extracting the LULC for site: SOILSCAPE_node412
# Extracting the LULC for site: SOILSCAPE_node413
# Extracting the LULC for site: SOILSCAPE_node414
# Extracting the LULC for site: SOILSCAPE_node415
# Extracting the LULC for site: SOILSCAPE_node416
# Extracting the LULC for site: SOILSCAPE_node417
# Extracting the LULC for site: SOILSCAPE_node418
# Extracting the LULC for site: SOILSCAPE_node419
# Extracting the LULC for site: SOILSCAPE_node420
# Extracting the LULC for site: SOILSCAPE_node501
# Extracting the LULC for site: SOILSCAPE_node503
# Extracting the LULC for site: SOILSCAPE_node504
# Extracting the LULC for site: SOILSCAPE_node505
# Extracting the LULC for site: SOILSCAPE_node506
# Extracting the LULC for site: SOILSCAPE_node508
# Extracting the LULC for site: SOILSCAPE_node509
# Extracting the LULC for site: SOILSCAPE_node510
# Extracting the LULC for site: SOILSCAPE_node511
# Extracting the LULC for site: SOILSCAPE_node512
# Extracting the LULC for site: SOILSCAPE_node513
# Extracting the LULC for site: SOILSCAPE_node514
# Extracting the LULC for site: SOILSCAPE_node515
# Extracting the LULC for site: SOILSCAPE_node518
# Extracting the LULC for site: SOILSCAPE_node701
# Extracting the LULC for site: SOILSCAPE_node704
# Extracting the LULC for site: SOILSCAPE_node708
# Extracting the LULC for site: SOILSCAPE_node709
# Extracting the LULC for site: SOILSCAPE_node710
# Extracting the LULC for site: SOILSCAPE_node712
# Extracting the LULC for site: SOILSCAPE_node713
# Extracting the LULC for site: SOILSCAPE_node900
# Extracting the LULC for site: SOILSCAPE_node901
# Extracting the LULC for site: SOILSCAPE_node902
# Extracting the LULC for site: SOILSCAPE_node903
# Extracting the LULC for site: SOILSCAPE_node904
# Extracting the LULC for site: SOILSCAPE_node905
# Extracting the LULC for site: SOILSCAPE_node906
# Extracting the LULC for site: SOILSCAPE_node907
# Extracting the LULC for site: SOILSCAPE_node908
# Extracting the LULC for site: SOILSCAPE_node909
# Extracting the LULC for site: SOILSCAPE_node911
# Extracting the LULC for site: SOILSCAPE_node912
# Extracting the LULC for site: SOILSCAPE_node913
# Extracting the LULC for site: SOILSCAPE_node914
# Extracting the LULC for site: SOILSCAPE_node915
# Extracting the LULC for site: SOILSCAPE_node916
# Extracting the LULC for site: USCRN_Aberdeen_35_WNW
# Extracting the LULC for site: USCRN_Arco_17_SW
# Extracting the LULC for site: USCRN_Asheville_13_S
# Extracting the LULC for site: USCRN_Asheville_8_SSW
# Extracting the LULC for site: USCRN_Austin_33_NW
# Extracting the LULC for site: USCRN_Avondale_2_N
# Extracting the LULC for site: USCRN_Baker_5_W
# Extracting the LULC for site: USCRN_Batesville_8_WNW
# Extracting the LULC for site: USCRN_Bedford_5_WNW
# Extracting the LULC for site: USCRN_Blackville_3_W
# Extracting the LULC for site: USCRN_Bodega_6_WSW
# Extracting the LULC for site: USCRN_Boulder_14_W
# Extracting the LULC for site: USCRN_Bowling_Green_21_NNE
# Extracting the LULC for site: USCRN_Brigham_City_28_WNW
# Extracting the LULC for site: USCRN_Bronte_11_NNE
# Extracting the LULC for site: USCRN_Brunswick_23_S
# Extracting the LULC for site: USCRN_Buffalo_13_ESE
# Extracting the LULC for site: USCRN_Cape_Charles_5_ENE
# Extracting the LULC for site: USCRN_Champaign_9_SW
# Extracting the LULC for site: USCRN_Charlottesville_2_SSE
# Extracting the LULC for site: USCRN_Chatham_1_SE
# Extracting the LULC for site: USCRN_Chillicothe_22_ENE
# Extracting the LULC for site: USCRN_Cortez_8_SE
# Extracting the LULC for site: USCRN_Corvallis_10_SSW
# Extracting the LULC for site: USCRN_Coshocton_8_NNE
# Extracting the LULC for site: USCRN_Crossville_7_NW
# Extracting the LULC for site: USCRN_Darrington_21_NNE
# Extracting the LULC for site: USCRN_Denio_52_WSW
# Extracting the LULC for site: USCRN_Des_Moines_17_E
# Extracting the LULC for site: USCRN_Dillon_18_WSW
# Extracting the LULC for site: USCRN_Dinosaur_2_E
# Extracting the LULC for site: USCRN_Durham_11_W
# Extracting the LULC for site: USCRN_Durham_2_N
# Extracting the LULC for site: USCRN_Durham_2_SSW
# Extracting the LULC for site: USCRN_Edinburg_17_NNE
# Extracting the LULC for site: USCRN_Elgin_5_S
# Extracting the LULC for site: USCRN_Elkins_21_ENE
# Extracting the LULC for site: USCRN_Everglades_City_5_NE
# Extracting the LULC for site: USCRN_Fairhope_3_NE
# Extracting the LULC for site: USCRN_Fallbrook_5_NE
# Extracting the LULC for site: USCRN_Gadsden_19_N
# Extracting the LULC for site: USCRN_Gaylord_9_SSW
# Extracting the LULC for site: USCRN_Goodridge_12_NNW
# Extracting the LULC for site: USCRN_Goodwell_2_E
# Extracting the LULC for site: USCRN_Goodwell_2_SE
# Extracting the LULC for site: USCRN_Harrison_20_SSE
# Extracting the LULC for site: USCRN_Holly_Springs_4_N
# Extracting the LULC for site: USCRN_Ithaca_13_E
# Extracting the LULC for site: USCRN_Jamestown_38_WSW
# Extracting the LULC for site: USCRN_John_Day_35_WNW
# Extracting the LULC for site: USCRN_Joplin_24_N
# Extracting the LULC for site: USCRN_Kingston_1_NW
# Extracting the LULC for site: USCRN_Kingston_1_W
# Extracting the LULC for site: USCRN_La_Junta_17_WSW
# Extracting the LULC for site: USCRN_Lafayette_13_SE
# Extracting the LULC for site: USCRN_Lander_11_SSE
# Extracting the LULC for site: USCRN_Las_Cruces_20_N
# Extracting the LULC for site: USCRN_Lewistown_42_WSW
# Extracting the LULC for site: USCRN_Limestone_4_NNW
# Extracting the LULC for site: USCRN_Lincoln_11_SW
# Extracting the LULC for site: USCRN_Lincoln_8_ENE
# Extracting the LULC for site: USCRN_Los_Alamos_13_W
# Extracting the LULC for site: USCRN_Manhattan_6_SSW
# Extracting the LULC for site: USCRN_McClellanville_7_NE
# Extracting the LULC for site: USCRN_Medora_7_E
# Extracting the LULC for site: USCRN_Merced_23_WSW
# Extracting the LULC for site: USCRN_Mercury_3_SSW
# Extracting the LULC for site: USCRN_Millbrook_3_W
# Extracting the LULC for site: USCRN_Monahans_6_ENE
# Extracting the LULC for site: USCRN_Monroe_26_N
# Extracting the LULC for site: USCRN_Montrose_11_ENE
# Extracting the LULC for site: USCRN_Moose_1_NNE
# Extracting the LULC for site: USCRN_Muleshoe_19_S
# Extracting the LULC for site: USCRN_Murphy_10_W
# Extracting the LULC for site: USCRN_Necedah_5_WNW
# Extracting the LULC for site: USCRN_Newton_11_SW
# Extracting the LULC for site: USCRN_Newton_5_ENE
# Extracting the LULC for site: USCRN_Newton_8_W
# Extracting the LULC for site: USCRN_Northgate_5_ESE
# Extracting the LULC for site: USCRN_Nunn_7_NNE
# Extracting the LULC for site: USCRN_Oakley_19_SSW
# Extracting the LULC for site: USCRN_Old_Town_2_W
# Extracting the LULC for site: USCRN_Palestine_6_WNW
# Extracting the LULC for site: USCRN_Panther_Junction_2_N
# Extracting the LULC for site: USCRN_Pierre_24_S
# Extracting the LULC for site: USCRN_Port_Aransas_32_NNE
# Extracting the LULC for site: USCRN_Quinault_4_NE
# Extracting the LULC for site: USCRN_Redding_12_WNW
# Extracting the LULC for site: USCRN_Riley_10_WSW
# Extracting the LULC for site: USCRN_Salem_10_W
# Extracting the LULC for site: USCRN_Sandstone_6_W
# Extracting the LULC for site: USCRN_Santa_Barbara_11_W
# Extracting the LULC for site: USCRN_Sebring_23_SSE
# Extracting the LULC for site: USCRN_Selma_13_WNW
# Extracting the LULC for site: USCRN_Shabbona_5_NNE
# Extracting the LULC for site: USCRN_Sioux_Falls_14_NNE
# Extracting the LULC for site: USCRN_Socorro_20_N
# Extracting the LULC for site: USCRN_Spokane_17_SSW
# Extracting the LULC for site: USCRN_St._Mary_1_SSW
# Extracting the LULC for site: USCRN_Stillwater_2_W
# Extracting the LULC for site: USCRN_Stillwater_5_WNW
# Extracting the LULC for site: USCRN_Stovepipe_Wells_1_SW
# Extracting the LULC for site: USCRN_Sundance_8_NNW
# Extracting the LULC for site: USCRN_Titusville_7_E
# Extracting the LULC for site: USCRN_Tucson_11_W
# Extracting the LULC for site: USCRN_Versailles_3_NNW
# Extracting the LULC for site: USCRN_Watkinsville_5_SSE
# Extracting the LULC for site: USCRN_Whitman_5_ENE
# Extracting the LULC for site: USCRN_Williams_35_NNW
# Extracting the LULC for site: USCRN_Wolf_Point_29_ENE
# Extracting the LULC for site: USCRN_Wolf_Point_34_NE
# Extracting the LULC for site: USCRN_Yosemite_Village_12_W
# Extracting the LULC for site: USCRN_Yuma_27_ENE

# %% [markdown]
# ## Calculate global averaged SMAP soil moisture
